# %% [markdown]
# # TFM - Ingesta de Datos desde Yelp a MongoDB Atlas
#
# Este notebook implementa el pipeline de ingesta de datos para el proyecto:
#
# **Título del TFM**: Análisis de Datos y Procesamiento de Lenguaje Natural para la Extracción de Opiniones y Modelado de Tópicos en Restaurantes: Un Enfoque de Big Data y Ciencia de Datos Aplicado al Estudio Integral del Sector Gastronómico
#
# ## Objetivo del Notebook
# Implementar un pipeline de datos que:
# 1. Lea los archivos JSON del dataset de Yelp
# 2. Cargue todos los datos en MongoDB Atlas para su posterior análisis
# 3. Analice las categorías de negocios disponibles
# 4. Filtre los negocios relevantes (restaurantes)
# 5. Extraiga restaurantes con sus reviews para análisis de NLP
#
# ## Estructura de Datos
# El dataset de Yelp incluye varios archivos JSON:
# - `yelp_academic_dataset_business.json`: Información de negocios (ubicación, categorías, etc.)
# - `yelp_academic_dataset_review.json`: Reseñas de usuarios con texto y calificaciones
# - `yelp_academic_dataset_user.json`: Información de usuarios
# - `yelp_academic_dataset_checkin.json`: Check-ins en negocios
# - `yelp_academic_dataset_tip.json`: Tips cortos de usuarios
#
# **Para este proyecto nos enfocaremos únicamente en `business` y `review`** ya que contienen la información necesaria para nuestro análisis de sentimientos y modelado de tópicos en restaurantes.

# %% [markdown]
# ## 1. Instalación y Configuración
#
# Necesitamos las siguientes librerías:
# - `pymongo`: Para conectar con MongoDB Atlas
# - `pandas`: Para el manejo eficiente de datos
#
# ### Nota sobre las herramientas utilizadas
#
# En este notebook usamos:
# - **uv**: Un instalador de paquetes Python ultrarrápido y confiable que reemplaza a pip
#
# ### Instalamos las dependencias necesarias con uv (instalador rápido de Python)
#
# `uv add pymongo tqdm python-dotenv pandas`

# %% [markdown]
# ## 2. Conexión a MongoDB Atlas
#
# ⚠️ **IMPORTANTE: Seguridad de las Credenciales**
# - Nunca subas tu contraseña a un repositorio
# - Usa variables de entorno o archivos .env para las credenciales
# - Asegúrate de que tu IP esté en la whitelist de MongoDB Atlas
#
# ### Configuración del archivo .env
#
# Para mayor seguridad, es recomendable guardar las credenciales en un archivo `.env` en el directorio raíz del proyecto:
#
# ```
# # Archivo .env (coloca este archivo en la raíz del proyecto)
# MONGODB_PASSWORD=tu_contraseña_real
# ```
#
# Asegúrate de que este archivo esté incluido en `.gitignore` para evitar subirlo accidentalmente al repositorio.

# %%
import os
import json
import time
import pathlib
from dotenv import load_dotenv
from pymongo import MongoClient
from pymongo.server_api import ServerApi
from tqdm import tqdm
import pandas as pd

# %% [markdown]
# ## 3. Configuración de la Conexión

# %% [markdown]
# ### Configuración de la conexión MongoDB
#
# Configuramos la conexión con timeouts extendidos para manejar operaciones de datos grandes:
# - **Socket Timeout**: 5 minutos para operaciones largas
# - **Connection Timeout**: 5 minutos para conexiones lentas
# - **Connection Pool**: 50 conexiones máximo para eficiencia
# - **Retry Writes/Reads**: Reintenta automáticamente en caso de fallos temporales
#
# ### Verificación de la conexión
# Hacemos un ping a MongoDB Atlas para asegurar que:
# - Las credenciales son correctas
# - La conexión funciona
# - El cluster está disponible

# %%
# Cargar variables de entorno desde archivo .env

# Opción 1: Ruta relativa simple (recomendada para notebooks)
load_dotenv('../.env')

# Opción 2: Ruta absoluta como fallback
project_root = pathlib.Path().resolve().parent
dotenv_path = project_root / '.env'
if dotenv_path.exists():
    load_dotenv(dotenv_path)
    print(f"Archivo .env encontrado en: {dotenv_path}")
else:
    print(f"Archivo .env no encontrado en: {dotenv_path}")

# Configuración de la conexión a MongoDB Atlas
PASSWORD = os.environ.get("MONGODB_PASSWORD")  # Obtener la contraseña del archivo .env

# Verificar que la contraseña existe
if not PASSWORD:
    print("Error: No se encontró la variable MONGODB_PASSWORD en el archivo .env")
    print("Por favor, crea un archivo .env con la variable MONGODB_PASSWORD=tu_contraseña_real")
    print(f"Variables de entorno disponibles que empiezan con 'MONGO': {[k for k in os.environ.keys() if 'MONGO' in k]}")
else:
    print("Variable MONGODB_PASSWORD encontrada correctamente")
    
    # URI mejorada con timeouts más largos (basada en el template de configuración)
    uri = f"mongodb+srv://juank920621:{PASSWORD}@cluster0.tsbdbxg.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0"

    # Crear cliente de MongoDB con configuración mejorada para evitar timeouts
    client = MongoClient(
        uri, 
        server_api=ServerApi('1'),
        socketTimeoutMS=300000,          # 5 minutos socket timeout
        connectTimeoutMS=300000,         # 5 minutos connection timeout  
        serverSelectionTimeoutMS=300000, # 5 minutos server selection timeout
        maxPoolSize=50,                  # Max connection pool size
        retryWrites=True,                # Enable retryable writes
        retryReads=True                  # Enable retryable reads
    )

    try:
        # Verificar la conexión con timeout
        print("Intentando conectar a MongoDB Atlas...")
        client.admin.command('ping')
        print("Conexión exitosa a MongoDB Atlas")
        
        # Crear/seleccionar la base de datos y colecciones
        db = client['tfm_yelp_db']
        businesses_collection = db['businesses']
        reviews_collection = db['reviews']
        
        print("Base de datos y colecciones configuradas:")
        print(f"   - Database: {db.name}")
        print(f"   - Collections: {', '.join([businesses_collection.name, reviews_collection.name])}")
        
    except Exception as e:
        print("Error al conectar a MongoDB Atlas:")
        print(f"Error details: {e}")
        print("\n Pasos de solución:")
        print("1. Verifica que tu IP esté en la whitelist de MongoDB Atlas")
        print("2. Asegúrate de que el cluster no esté pausado")
        print("3. Verifica tu conexión a internet")
        print("4. Revisa que el firewall no bloquee los puertos 27017-27019")
        print("5. Confirma que la contraseña en el archivo .env sea correcta")
# Out:
# Archivo .env encontrado en: /home/juangarzon/Master-Big-Data/M10. Trabajo Final de Máster/tfm-proyecto/.env
# Variable MONGODB_PASSWORD encontrada correctamente
# Intentando conectar a MongoDB Atlas...
# Conexión exitosa a MongoDB Atlas
# Base de datos y colecciones configuradas:
#    - Database: tfm_yelp_db
#    - Collections: businesses, reviews

# %% [markdown]
# ### Limpieza de colecciones existentes
#
# Antes de cargar nuevos datos, eliminamos las colecciones existentes para evitar duplicados:
# - Se eliminan las colecciones `businesses` y `reviews`
# - Esto asegura que empezamos con datos limpios en cada ejecución

# %%
# Drop collections for clean start
print("Dropping existing collections...")

# Drop both collections
db['businesses'].drop()
db['reviews'].drop()

print("Collections dropped successfully.")
# Out:
# Dropping existing collections...
# Collections dropped successfully.

# %% [markdown]
# ## 4. Importación de datos JSON a MongoDB Atlas
#
# En esta sección cargamos los archivos principales del dataset de Yelp a MongoDB Atlas:
#
# **Archivos que procesamos:**
# 1. **`yelp_academic_dataset_business.json`**: Información de negocios
# 2. **`yelp_academic_dataset_review.json`**: Reseñas de usuarios
#
# **Características del proceso:**
# - **Formato**: JSON Lines (un documento por línea)
# - **Método**: Inserción en lotes de 5,000 documentos
# - **Progreso**: Barras de progreso con tqdm para visualizar el avance
# - **Manejo de errores**: Continúa procesando aunque encuentre documentos malformados
#
# **Colecciones creadas:**
# - `businesses`: Información sobre los negocios
# - `reviews`: Reseñas realizadas por los usuarios
#
# > **Nota:** Si los archivos son muy grandes, asegúrate de tener una conexión estable a internet. El proceso puede tomar varios minutos dependiendo del tamaño de los datos.

# %%
# Script de ingesta de datos para el dataset de Yelp

# Configuración
DATA_FILES = {
    "businesses": "../data/raw/yelp_academic_dataset_business.json",
    "reviews": "../data/raw/yelp_academic_dataset_review.json"
}
BATCH_SIZE = 5000

def load_data_to_mongodb(db, files_config, batch_size=5000):
    """Cargar archivos JSON line a colecciones de MongoDB con barras de progreso detalladas."""
    
    for collection_name, file_path in files_config.items():
        if not os.path.exists(file_path):
            print(f"Error: File not found - {file_path}")
            continue
            
        print(f"\nLoading {collection_name}...")
        collection = db[collection_name]
        
        # Contar líneas totales para la barra de progreso
        print(f"Counting lines in {file_path}...")
        with open(file_path, 'r', encoding='utf-8') as f:
            total_lines = sum(1 for _ in f)
        
        print(f"Total lines to process: {total_lines:,}")
        
        # Insertar datos en lotes con progreso detallado
        with open(file_path, 'r', encoding='utf-8') as f:
            batch = []
            total_inserted = 0
            total_processed = 0
            
            # Usar context manager para tqdm para asegurar limpieza adecuada
            with tqdm(
                total=total_lines,
                desc=f"Processing {collection_name}",
                unit="docs",
                unit_scale=True,
                bar_format="{l_bar}{bar}| {n_fmt}/{total_fmt} [{elapsed}<{remaining}, {rate_fmt}] Inserted: {postfix}",
                leave=True,
                disable=False
            ) as pbar:
                
                for line in f:
                    total_processed += 1
                    try:
                        document = json.loads(line.strip())
                        batch.append(document)
                        
                        if len(batch) >= batch_size:
                            # Insertar lote con indicador de progreso mini
                            collection.insert_many(batch)
                            total_inserted += len(batch)
                            batch = []
                            
                            # Actualizar barra de progreso con información de inserción
                            pbar.set_postfix_str(f"{total_inserted:,}")
                        
                        # Actualizar barra de progreso
                        pbar.update(1)
                            
                    except json.JSONDecodeError as e:
                        # Saltar líneas JSON malformadas
                        pbar.update(1)
                        continue
                
                # Insertar documentos restantes
                if batch:
                    collection.insert_many(batch)
                    total_inserted += len(batch)
                    pbar.set_postfix_str(f"{total_inserted:,}")
        
        print(f"Completed {collection_name}: {total_inserted:,} documents inserted from {total_processed:,} lines processed")

# Ejecutar carga de datos con seguimiento de progreso mejorado
print("Starting data ingestion process...")
load_data_to_mongodb(db, DATA_FILES, BATCH_SIZE)

# Verificar conteos finales
print("\nFinal collection summary:")
for collection_name in DATA_FILES.keys():
    count = db[collection_name].count_documents({})
    print(f"   {collection_name}: {count:,} documents")

print("\nData ingestion completed successfully!")
# Out:
# Starting data ingestion process...
#
# Loading businesses...
# Counting lines in ../data/raw/yelp_academic_dataset_business.json...
# Total lines to process: 150,346
# Processing businesses: 100%|██████████| 150k/150k [00:46<00:00, 3.24kdocs/s] Inserted: , 150,346
# Completed businesses: 150,346 documents inserted from 150,346 lines processed
#
# Loading reviews...
# Counting lines in ../data/raw/yelp_academic_dataset_review.json...
# Total lines to process: 6,990,280
# Processing reviews: 100%|██████████| 6.99M/6.99M [35:34<00:00, 3.27kdocs/s] Inserted: , 6,990,280
# Completed reviews: 6,990,280 documents inserted from 6,990,280 lines processed
#
# Final collection summary:
#    businesses: 150,346 documents
#    reviews: 6,990,280 documents
#
# Data ingestion completed successfully!

# %% [markdown]
# ## 5. Verificación de la Ingesta de Datos
#
# Una vez completada la carga, verificamos que todo se haya procesado correctamente:
#
# ### Conteo de documentos por colección
# Verificamos cuántos documentos se insertaron en cada colección:
# - `businesses`: Debería mostrar ~150K documentos
# - `reviews`: Debería mostrar ~7M documentos
#
# ### Inspección de la estructura de datos
# Examinamos un documento de muestra de cada colección para:
# - Verificar que el formato JSON se preservó correctamente
# - Identificar los campos disponibles para análisis
# - Validar que no hay problemas de encoding con caracteres especiales
#
# Esto nos da una idea de cómo están estructurados nuestros datos antes de continuar.

# %%
# Verificación inicial de las colecciones
for coleccion in DATA_FILES.keys():
    count = db[coleccion].count_documents({})
    print(f"{coleccion}: {count:,} documentos")
# Out:
# businesses: 150,346 documentos
# reviews: 6,990,280 documentos

# %%
# Mostrar un documento de ejemplo de cada colección
for coleccion in DATA_FILES.keys():
    doc = db[coleccion].find_one()
    print(f"\nPrimer documento de '{coleccion}':\n{json.dumps(doc, indent=2, ensure_ascii=False, default=str)}")
# Out:
# Primer documento de 'businesses':
# {
#   "_id": "686eadc415b72f78f153cf15",
#   "business_id": "Pns2l4eNsfO8kk83dixA6A",
#   "name": "Abby Rappoport, LAC, CMQ",
#   "address": "1616 Chapala St, Ste 2",
#   "city": "Santa Barbara",
#   "state": "CA",
#   "postal_code": "93101",
#   "latitude": 34.4266787,
#   "longitude": -119.7111968,
#   "stars": 5.0,
#   "review_count": 7,
#   "is_open": 0,
#   "attributes": {
#     "ByAppointmentOnly": "True"
#   },
#   "categories": "Doctors, Traditional Chinese Medicine, Naturopathic/Holistic, Acupuncture, Health & Medical, Nutritionists",
#   "hours": null
# }
#
# Primer documento de 'reviews':
# {
#   "_id": "686eadf615b72f78f1561a5f",
#   "review_id": "KU_O5udG6zpxOg-VcAEodg",
#   "user_id": "mh_-eMZ6K5RLWhZyISBhwA",
#   "business_id": "XQfwVwDr-v0ZS3_CbbE5Xw",
#   "stars": 3.0,
#   "useful": 0,
#   "funny": 0,
#   "cool": 0,
#   "text": "If you decide to eat here, just be aware it is going to take about 2 hours from beginning to end. We have tried it multiple times, because I want to like it! I have been to it's other locations in NJ and never had a bad experience. \n\nThe food is good, but it takes a very long time to come out. The waitstaff is very young, but usually pleasant. We have just had too many experiences where we spent way too long waiting. We usually opt for another diner or restaurant on the weekends, in order to be done quicker.",
#   "date": "2018-07-07 22:09:11"
# }

# %% [markdown]
# ## 6. Análisis de Categorías de Negocios
#
# Antes de filtrar los restaurantes, analizamos qué tipos de negocios tenemos en el dataset.
#
# ### ¿Por qué analizar las categorías?
# - El campo `categories` contiene múltiples categorías separadas por comas
# - Necesitamos entender la distribución para filtrar correctamente
# - Queremos asegurar que capturamos todos los restaurantes sin incluir negocios irrelevantes
#
# ### Pipeline de análisis
# Usamos un pipeline de agregación de MongoDB para:
# 1. Dividir las categorías (separadas por comas) en elementos individuales
# 2. Contar cuántos negocios hay por categoría
# 3. Mostrar las 50 categorías más comunes
#
# Esto nos ayuda a entender qué tipos de negocios dominan el dataset.
#
# ### Filtrado de restaurantes
# Para nuestro análisis, buscamos específicamente negocios que tengan "Restaurants" en sus categorías:
# - Usamos una expresión regular `\bRestaurants\b` para buscar la palabra exacta
# - Esto evita falsos positivos como "Restaurant Supplies" o "Restaurant Equipment"
# - Nos aseguramos de capturar solo restaurantes reales

# %%
pipeline_categories = [
    {"$match": {"categories": {"$exists": True}}},
    {"$project": {"categories": {"$split": ["$categories", ", "]}}},
    {"$unwind": "$categories"},
    {"$group": {"_id": "$categories", "count": {"$sum": 1}}},
    {"$sort": {"count": -1}},
]

categories_cursor = db["businesses"].aggregate(pipeline_categories)

for cat in categories_cursor:
    print(cat)
# Out:
# {'_id': 'Restaurants', 'count': 52268}
# {'_id': 'Food', 'count': 27781}
# {'_id': 'Shopping', 'count': 24395}
# {'_id': 'Home Services', 'count': 14356}
# {'_id': 'Beauty & Spas', 'count': 14292}
# {'_id': 'Nightlife', 'count': 12281}
# {'_id': 'Health & Medical', 'count': 11890}
# {'_id': 'Local Services', 'count': 11198}
# {'_id': 'Bars', 'count': 11065}
# {'_id': 'Automotive', 'count': 10773}
# {'_id': 'Event Planning & Services', 'count': 9895}
# {'_id': 'Sandwiches', 'count': 8366}
# {'_id': 'American (Traditional)', 'count': 8139}
# {'_id': 'Active Life', 'count': 7687}
# {'_id': 'Pizza', 'count': 7093}
# {'_id': 'Coffee & Tea', 'count': 6703}
# {'_id': 'Fast Food', 'count': 6472}
# {'_id': 'Breakfast & Brunch', 'count': 6239}
# {'_id': 'American (New)', 'count': 6097}
# {'_id': 'Hotels & Travel', 'count': 5857}
# {'_id': 'Home & Garden', 'count': 5799}
# {'_id': 'Fashion', 'count': 5739}
# {'_id': 'Burgers', 'count': 5636}
# {'_id': 'Arts & Entertainment', 'count': 5434}
# {'_id': 'Auto Repair', 'count': 5433}
# {'_id': 'Hair Salons', 'count': 5046}
# {'_id': 'Nail Salons', 'count': 4621}
# {'_id': 'Mexican', 'count': 4600}
# {'_id': 'Italian', 'count': 4573}
# {'_id': 'Specialty Food', 'count': 4233}
# {'_id': 'Doctors', 'count': 3763}
# {'_id': 'Pets', 'count': 3758}
# {'_id': 'Real Estate', 'count': 3577}
# {'_id': 'Seafood', 'count': 3539}
# {'_id': 'Fitness & Instruction', 'count': 3293}
# {'_id': 'Professional Services', 'count': 3270}
# {'_id': 'Hair Removal', 'count': 3239}
# {'_id': 'Desserts', 'count': 3186}
# {'_id': 'Chinese', 'count': 3169}
# {'_id': 'Bakeries', 'count': 3150}
# {'_id': 'Grocery', 'count': 3139}
# {'_id': 'Salad', 'count': 3064}
# {'_id': 'Hotels', 'count': 2977}
# {'_id': 'Chicken Wings', 'count': 2966}
# {'_id': 'Cafes', 'count': 2756}
# {'_id': 'Ice Cream & Frozen Yogurt', 'count': 2657}
# {'_id': 'Caterers', 'count': 2645}
# {'_id': 'Pet Services', 'count': 2626}
# {'_id': 'Dentists', 'count': 2528}
# {'_id': 'Skin Care', 'count': 2498}
# {'_id': 'Venues & Event Spaces', 'count': 2480}
# {'_id': 'Tires', 'count': 2471}
# {'_id': 'Beer', 'count': 2413}
# {'_id': 'Wine & Spirits', 'count': 2413}
# {'_id': 'Delis', 'count': 2393}
# {'_id': 'Oil Change Stations', 'count': 2356}
# {'_id': 'Waxing', 'count': 2333}
# {'_id': 'Contractors', 'count': 2327}
# {'_id': "Women's Clothing", 'count': 2184}
# {'_id': 'Massage', 'count': 2134}
# {'_id': 'Sports Bars', 'count': 2110}
# {'_id': 'Day Spas', 'count': 1997}
# {'_id': 'General Dentistry', 'count': 1993}
# {'_id': 'Education', 'count': 1936}
# {'_id': 'Flowers & Gifts', 'count': 1930}
# {'_id': 'Auto Parts & Supplies', 'count': 1926}
# {'_id': 'Apartments', 'count': 1921}
# {'_id': 'Convenience Stores', 'count': 1919}
# {'_id': 'Home Decor', 'count': 1892}
# {'_id': 'Gyms', 'count': 1831}
# {'_id': 'Japanese', 'count': 1830}
# {'_id': 'Pubs', 'count': 1821}
# {'_id': 'Cocktail Bars', 'count': 1718}
# {'_id': 'Sushi Bars', 'count': 1717}
# {'_id': 'Barbeque', 'count': 1694}
# {'_id': 'Juice Bars & Smoothies', 'count': 1684}
# {'_id': 'Barbers', 'count': 1677}
# {'_id': 'Car Dealers', 'count': 1665}
# {'_id': 'Sporting Goods', 'count': 1662}
# {'_id': 'Accessories', 'count': 1639}
# {'_id': 'Cosmetic Dentists', 'count': 1630}
# {'_id': 'Drugstores', 'count': 1630}
# {'_id': 'Local Flavor', 'count': 1604}
# {'_id': 'Furniture Stores', 'count': 1597}
# {'_id': 'Pet Groomers', 'count': 1549}
# {'_id': 'Asian Fusion', 'count': 1547}
# {'_id': 'Cosmetics & Beauty Supply', 'count': 1544}
# {'_id': 'Jewelry', 'count': 1525}
# {'_id': 'Steakhouses', 'count': 1506}
# {'_id': 'Diners', 'count': 1494}
# {'_id': 'Financial Services', 'count': 1487}
# {'_id': 'Trainers', 'count': 1460}
# {'_id': 'Hair Stylists', 'count': 1459}
# {'_id': 'Arts & Crafts', 'count': 1440}
# {'_id': 'Department Stores', 'count': 1430}
# {'_id': 'Electronics', 'count': 1422}
# {'_id': 'Veterinarians', 'count': 1383}
# {'_id': 'Massage Therapy', 'count': 1357}
# {'_id': 'Pet Sitting', 'count': 1356}
# {'_id': 'Eyelash Service', 'count': 1278}
# {'_id': "Men's Clothing", 'count': 1273}
# {'_id': 'Food Trucks', 'count': 1273}
# {'_id': 'Mediterranean', 'count': 1263}
# {'_id': 'Body Shops', 'count': 1229}
# {'_id': 'Public Services & Government', 'count': 1216}
# {'_id': 'Heating & Air Conditioning/HVAC', 'count': 1199}
# {'_id': 'Lounges', 'count': 1194}
# {'_id': 'Wine Bars', 'count': 1192}
# {'_id': 'IT Services & Computer Repair', 'count': 1189}
# {'_id': 'Vegetarian', 'count': 1158}
# {'_id': 'Laundry Services', 'count': 1149}
# {'_id': 'Medical Centers', 'count': 1131}
# {'_id': 'Optometrists', 'count': 1112}
# {'_id': 'Plumbing', 'count': 1111}
# {'_id': 'Gas Stations', 'count': 1106}
# {'_id': 'Music Venues', 'count': 1104}
# {'_id': 'Donuts', 'count': 1097}
# {'_id': 'Dry Cleaning & Laundry', 'count': 1075}
# {'_id': 'Party & Event Planning', 'count': 1073}
# {'_id': 'Soup', 'count': 1061}
# {'_id': 'Food Delivery Services', 'count': 1050}
# {'_id': 'Pet Stores', 'count': 1043}
# {'_id': 'Tacos', 'count': 1020}
# {'_id': 'Shoe Stores', 'count': 1018}
# {'_id': 'Eyewear & Opticians', 'count': 1016}
# {'_id': 'Southern', 'count': 988}
# {'_id': 'Parks', 'count': 984}
# {'_id': 'Mags', 'count': 975}
# {'_id': 'Music & Video', 'count': 975}
# {'_id': 'Books', 'count': 975}
# {'_id': 'Makeup Artists', 'count': 973}
# {'_id': 'Thai', 'count': 971}
# {'_id': 'Car Wash', 'count': 960}
# {'_id': 'Florists', 'count': 955}
# {'_id': 'Building Supplies', 'count': 954}
# {'_id': 'Mobile Phones', 'count': 952}
# {'_id': 'Movers', 'count': 948}
# {'_id': 'Yoga', 'count': 938}
# {'_id': 'Specialty Schools', 'count': 932}
# {'_id': 'Cajun/Creole', 'count': 923}
# {'_id': 'Tex-Mex', 'count': 919}
# {'_id': 'Auto Detailing', 'count': 906}
# {'_id': 'Landscaping', 'count': 896}
# {'_id': 'Nurseries & Gardening', 'count': 892}
# {'_id': 'Appliances', 'count': 872}
# {'_id': 'Beer Bar', 'count': 870}
# {'_id': 'Discount Store', 'count': 868}
# {'_id': 'Breweries', 'count': 863}
# {'_id': 'Transportation', 'count': 858}
# {'_id': 'Vegan', 'count': 856}
# {'_id': 'Vietnamese', 'count': 852}
# {'_id': 'Home Cleaning', 'count': 850}
# {'_id': 'Tours', 'count': 842}
# {'_id': 'Sewing & Alterations', 'count': 842}
# {'_id': 'Indian', 'count': 838}
# {'_id': "Men's Hair Salons", 'count': 828}
# {'_id': 'Latin American', 'count': 810}
# {'_id': 'Chicken Shop', 'count': 808}
# {'_id': 'Real Estate Services', 'count': 800}
# {'_id': 'Appliances & Repair', 'count': 800}
# {'_id': 'Gift Shops', 'count': 796}
# {'_id': 'Self Storage', 'count': 795}
# {'_id': 'Hardware Stores', 'count': 792}
# {'_id': 'Shipping Centers', 'count': 792}
# {'_id': 'Printing Services', 'count': 790}
# {'_id': 'Art Galleries', 'count': 786}
# {'_id': 'Medical Spas', 'count': 781}
# {'_id': 'Greek', 'count': 779}
# {'_id': 'Gluten-Free', 'count': 777}
# {'_id': 'Hot Dogs', 'count': 774}
# {'_id': 'Kitchen & Bath', 'count': 763}
# {'_id': 'Property Management', 'count': 759}
# {'_id': 'Vintage & Consignment', 'count': 753}
# {'_id': 'Used', 'count': 753}
# {'_id': 'Oral Surgeons', 'count': 752}
# {'_id': 'Banks & Credit Unions', 'count': 749}
# {'_id': 'Comfort Food', 'count': 746}
# {'_id': 'Bagels', 'count': 738}
# {'_id': 'Auto Glass Services', 'count': 727}
# {'_id': 'Chiropractors', 'count': 726}
# {'_id': 'Wedding Planning', 'count': 709}
# {'_id': 'Endodontists', 'count': 706}
# {'_id': 'Towing', 'count': 692}
# {'_id': 'Tobacco Shops', 'count': 691}
# {'_id': 'Car Rental', 'count': 670}
# {'_id': 'Tanning', 'count': 667}
# {'_id': 'Orthodontists', 'count': 660}
# {'_id': 'Ethnic Food', 'count': 658}
# {'_id': 'Transmission Repair', 'count': 639}
# {'_id': 'Antiques', 'count': 638}
# {'_id': 'Dive Bars', 'count': 636}
# {'_id': 'Mattresses', 'count': 630}
# {'_id': 'Hair Extensions', 'count': 624}
# {'_id': 'Buffets', 'count': 622}
# {'_id': 'Flooring', 'count': 621}
# {'_id': 'Cheesesteaks', 'count': 614}
# {'_id': 'Thrift Stores', 'count': 610}
# {'_id': 'Tattoo', 'count': 609}
# {'_id': 'Health Markets', 'count': 601}
# {'_id': 'Caribbean', 'count': 590}
# {'_id': 'Middle Eastern', 'count': 588}
# {'_id': 'Performing Arts', 'count': 581}
# {'_id': 'Sports Wear', 'count': 574}
# {'_id': 'Real Estate Agents', 'count': 565}
# {'_id': 'Tree Services', 'count': 561}
# {'_id': 'Physical Therapy', 'count': 561}
# {'_id': 'Pet Training', 'count': 561}
# {'_id': 'Water Heater Installation/Repair', 'count': 557}
# {'_id': 'Bridal', 'count': 555}
# {'_id': 'Hobby Shops', 'count': 552}
# {'_id': 'Meat Shops', 'count': 552}
# {'_id': 'Urgent Care', 'count': 541}
# {'_id': 'Soul Food', 'count': 539}
# {'_id': 'Fruits & Veggies', 'count': 532}
# {'_id': 'Pediatric Dentists', 'count': 528}
# {'_id': 'Carpet Cleaning', 'count': 526}
# {'_id': 'Mobile Phone Repair', 'count': 525}
# {'_id': 'Toy Stores', 'count': 518}
# {'_id': 'Notaries', 'count': 516}
# {'_id': 'Gastropubs', 'count': 513}
# {'_id': 'Interior Design', 'count': 509}
# {'_id': 'Photographers', 'count': 507}
# {'_id': 'Pest Control', 'count': 503}
# {'_id': 'French', 'count': 503}
# {'_id': 'Electronics Repair', 'count': 503}
# {'_id': 'Community Service/Non-Profit', 'count': 503}
# {'_id': 'Pharmacy', 'count': 503}
# {'_id': 'Family Practice', 'count': 503}
# {'_id': 'Farmers Market', 'count': 498}
# {'_id': 'Korean', 'count': 497}
# {'_id': 'Golf', 'count': 494}
# {'_id': 'Electricians', 'count': 489}
# {'_id': 'Bubble Tea', 'count': 477}
# {'_id': 'Vape Shops', 'count': 469}
# {'_id': 'Roofing', 'count': 468}
# {'_id': 'Mobile Phone Accessories', 'count': 468}
# {'_id': 'Diagnostic Services', 'count': 467}
# {'_id': 'Photography Stores & Services', 'count': 466}
# {'_id': 'Periodontists', 'count': 464}
# {'_id': 'Bikes', 'count': 463}
# {'_id': 'Blow Dry/Out Services', 'count': 456}
# {'_id': 'Eyebrow Services', 'count': 454}
# {'_id': 'Dance Clubs', 'count': 447}
# {'_id': 'Windows Installation', 'count': 447}
# {'_id': 'Painters', 'count': 446}
# {'_id': "Children's Clothing", 'count': 445}
# {'_id': 'Festivals', 'count': 442}
# {'_id': 'Weight Loss Centers', 'count': 441}
# {'_id': 'Tapas/Small Plates', 'count': 440}
# {'_id': 'Nutritionists', 'count': 439}
# {'_id': 'Used Car Dealers', 'count': 436}
# {'_id': 'Pet Boarding', 'count': 425}
# {'_id': 'Acupuncture', 'count': 424}
# {'_id': 'Food Stands', 'count': 423}
# {'_id': 'Cupcakes', 'count': 422}
# {'_id': 'Ophthalmologists', 'count': 421}
# {'_id': 'Bookstores', 'count': 416}
# {'_id': 'Child Care & Day Care', 'count': 416}
# {'_id': 'Museums', 'count': 413}
# {'_id': 'Reflexology', 'count': 411}
# {'_id': 'Insurance', 'count': 403}
# {'_id': 'Junk Removal & Hauling', 'count': 401}
# {'_id': 'Telecommunications', 'count': 397}
# {'_id': 'Hospitals', 'count': 395}
# {'_id': 'Laser Hair Removal', 'count': 394}
# {'_id': 'Dry Cleaning', 'count': 382}
# {'_id': 'Noodles', 'count': 382}
# {'_id': 'Arcades', 'count': 378}
# {'_id': 'Permanent Makeup', 'count': 377}
# {'_id': 'Office Cleaning', 'count': 373}
# {'_id': 'Outdoor Gear', 'count': 369}
# {'_id': 'Piercing', 'count': 368}
# {'_id': 'Cosmetic Surgeons', 'count': 367}
# {'_id': 'Kids Activities', 'count': 367}
# {'_id': 'Lawyers', 'count': 363}
# {'_id': 'Masonry/Concrete', 'count': 363}
# {'_id': 'Mortgage Brokers', 'count': 363}
# {'_id': 'Halal', 'count': 362}
# {'_id': 'Cinema', 'count': 359}
# {'_id': 'Session Photography', 'count': 357}
# {'_id': 'Street Vendors', 'count': 357}
# {'_id': 'Handyman', 'count': 356}
# {'_id': 'Candy Stores', 'count': 356}
# {'_id': 'Internet Service Providers', 'count': 356}
# {'_id': 'Damage Restoration', 'count': 353}
# {'_id': 'Windshield Installation & Repair', 'count': 352}
# {'_id': 'Jewelry Repair', 'count': 347}
# {'_id': 'Preschools', 'count': 344}
# {'_id': 'Wineries', 'count': 342}
# {'_id': 'Chocolatiers & Shops', 'count': 339}
# {'_id': 'Mailbox Centers', 'count': 339}
# {'_id': 'Computers', 'count': 339}
# {'_id': 'Seafood Markets', 'count': 337}
# {'_id': 'Boot Camps', 'count': 337}
# {'_id': 'Dermatologists', 'count': 336}
# {'_id': 'Lighting Fixtures & Equipment', 'count': 336}
# {'_id': 'Spray Tanning', 'count': 332}
# {'_id': 'Watches', 'count': 329}
# {'_id': 'Airport Shuttles', 'count': 328}
# {'_id': 'Post Offices', 'count': 327}
# {'_id': 'Karaoke', 'count': 325}
# {'_id': 'Event Photography', 'count': 325}
# {'_id': 'Bed & Breakfast', 'count': 324}
# {'_id': 'Keys & Locksmiths', 'count': 323}
# {'_id': 'Gutter Services', 'count': 320}
# {'_id': 'Nail Technicians', 'count': 320}
# {'_id': 'Couriers & Delivery Services', 'count': 317}
# {'_id': 'Sports Clubs', 'count': 314}
# {'_id': 'Pressure Washers', 'count': 313}
# {'_id': 'Obstetricians & Gynecologists', 'count': 311}
# {'_id': 'Art Supplies', 'count': 311}
# {'_id': 'Auto Customization', 'count': 311}
# {'_id': 'Wraps', 'count': 310}
# {'_id': 'Party Supplies', 'count': 309}
# {'_id': 'Carpeting', 'count': 304}
# {'_id': 'Wheel & Rim Repair', 'count': 303}
# {'_id': 'Landmarks & Historical Buildings', 'count': 302}
# {'_id': 'Pool & Hot Tub Service', 'count': 301}
# {'_id': 'Shopping Centers', 'count': 297}
# {'_id': 'Custom Cakes', 'count': 296}
# {'_id': 'Bike Rentals', 'count': 296}
# {'_id': 'Pilates', 'count': 294}
# {'_id': 'Limos', 'count': 293}
# {'_id': 'Organic Stores', 'count': 292}
# {'_id': 'Sports Medicine', 'count': 289}
# {'_id': 'Security Systems', 'count': 287}
# {'_id': 'Boating', 'count': 287}
# {'_id': 'Spanish', 'count': 286}
# {'_id': 'Religious Organizations', 'count': 286}
# {'_id': 'Home Inspectors', 'count': 286}
# {'_id': 'Dog Walkers', 'count': 284}
# {'_id': 'Cuban', 'count': 283}
# {'_id': 'Formal Wear', 'count': 279}
# {'_id': 'Amusement Parks', 'count': 279}
# {'_id': 'Swimming Pools', 'count': 278}
# {'_id': 'Coffee Roasteries', 'count': 278}
# {'_id': 'Door Sales/Installation', 'count': 277}
# {'_id': 'Musical Instruments & Teachers', 'count': 277}
# {'_id': 'Wholesale Stores', 'count': 274}
# {'_id': 'Bike Repair/Maintenance', 'count': 273}
# {'_id': 'Shaved Ice', 'count': 272}
# {'_id': 'Laboratory Testing', 'count': 272}
# {'_id': 'Air Duct Cleaning', 'count': 271}
# {'_id': 'Travel Services', 'count': 270}
# {'_id': 'Packing Services', 'count': 269}
# {'_id': 'Acai Bowls', 'count': 268}
# {'_id': 'Playgrounds', 'count': 266}
# {'_id': 'Shades & Blinds', 'count': 266}
# {'_id': 'Martial Arts', 'count': 265}
# {'_id': 'Canadian (New)', 'count': 261}
# {'_id': 'Office Equipment', 'count': 261}
# {'_id': 'Hot Tub & Pool', 'count': 257}
# {'_id': 'Shoe Repair', 'count': 256}
# {'_id': 'Floral Designers', 'count': 256}
# {'_id': 'Gardeners', 'count': 254}
# {'_id': 'Vitamins & Supplements', 'count': 253}
# {'_id': 'Pediatricians', 'count': 252}
# {'_id': 'Cards & Stationery', 'count': 252}
# {'_id': 'Taxis', 'count': 250}
# {'_id': 'Guns & Ammo', 'count': 245}
# {'_id': 'Car Stereo Installation', 'count': 245}
# {'_id': 'Recreation Centers', 'count': 244}
# {'_id': 'Parking', 'count': 243}
# {'_id': 'Baby Gear & Furniture', 'count': 242}
# {'_id': 'Art Classes', 'count': 241}
# {'_id': 'Watch Repair', 'count': 241}
# {'_id': 'Landscape Architects', 'count': 239}
# {'_id': 'Graphic Design', 'count': 238}
# {'_id': 'Tiling', 'count': 236}
# {'_id': 'Hookah Bars', 'count': 235}
# {'_id': 'Music & DVDs', 'count': 232}
# {'_id': 'Window Washing', 'count': 232}
# {'_id': 'Summer Camps', 'count': 232}
# {'_id': 'Tea Rooms', 'count': 228}
# {'_id': 'Pakistani', 'count': 228}
# {'_id': 'Car Window Tinting', 'count': 228}
# {'_id': 'Tapas Bars', 'count': 226}
# {'_id': 'Motorcycle Dealers', 'count': 226}
# {'_id': 'Counseling & Mental Health', 'count': 225}
# {'_id': 'Orthopedists', 'count': 225}
# {'_id': 'Ramen', 'count': 223}
# {'_id': 'Glass & Mirrors', 'count': 222}
# {'_id': 'Rehabilitation Center', 'count': 222}
# {'_id': 'Elementary Schools', 'count': 222}
# {'_id': 'Naturopathic/Holistic', 'count': 221}
# {'_id': 'Smog Check Stations', 'count': 220}
# {'_id': 'Churches', 'count': 218}
# {'_id': 'Adult Entertainment', 'count': 218}
# {'_id': 'Internal Medicine', 'count': 218}
# {'_id': 'Cabinetry', 'count': 216}
# {'_id': 'Irish', 'count': 215}
# {'_id': 'Hiking', 'count': 211}
# {'_id': 'Poke', 'count': 210}
# {'_id': 'Pool Cleaners', 'count': 207}
# {'_id': 'Libraries', 'count': 207}
# {'_id': 'Irrigation', 'count': 207}
# {'_id': 'Truck Rental', 'count': 206}
# {'_id': 'International Grocery', 'count': 205}
# {'_id': 'Motorcycle Repair', 'count': 204}
# {'_id': 'Signmaking', 'count': 204}
# {'_id': 'Interval Training Gyms', 'count': 203}
# {'_id': 'Fish & Chips', 'count': 202}
# {'_id': 'Dance Studios', 'count': 201}
# {'_id': 'Imported Food', 'count': 201}
# {'_id': 'Reiki', 'count': 201}
# {'_id': 'Lingerie', 'count': 201}
# {'_id': 'Head Shops', 'count': 201}
# {'_id': 'Fences & Gates', 'count': 200}
# {'_id': 'Laundromat', 'count': 198}
# {'_id': 'Auto Insurance', 'count': 198}
# {'_id': 'Framing', 'count': 197}
# {'_id': 'Gelato', 'count': 197}
# {'_id': 'Medical Supplies', 'count': 197}
# {'_id': 'Bowling', 'count': 195}
# {'_id': 'Party Equipment Rentals', 'count': 194}
# {'_id': 'Pasta Shops', 'count': 193}
# {'_id': 'Laser Eye Surgery/Lasik', 'count': 191}
# {'_id': 'Waffles', 'count': 190}
# {'_id': 'Brewpubs', 'count': 186}
# {'_id': 'Videos & Video Game Rental', 'count': 186}
# {'_id': 'Beer Gardens', 'count': 185}
# {'_id': 'Hawaiian', 'count': 185}
# {'_id': 'Butcher', 'count': 182}
# {'_id': 'Outlet Stores', 'count': 182}
# {'_id': 'Siding', 'count': 180}
# {'_id': 'Financial Advising', 'count': 179}
# {'_id': 'Jazz & Blues', 'count': 178}
# {'_id': 'Colleges & Universities', 'count': 177}
# {'_id': 'Diagnostic Imaging', 'count': 176}
# {'_id': 'Fabric Stores', 'count': 175}
# {'_id': 'Auto Loan Providers', 'count': 175}
# {'_id': 'Escape Games', 'count': 175}
# {'_id': 'Musical Instrument Services', 'count': 174}
# {'_id': 'Traditional Chinese Medicine', 'count': 174}
# {'_id': 'Resorts', 'count': 173}
# {'_id': 'Garage Door Services', 'count': 172}
# {'_id': 'Pool Halls', 'count': 171}
# {'_id': 'Packing Supplies', 'count': 170}
# {'_id': 'Dog Parks', 'count': 170}
# {'_id': 'Pet Adoption', 'count': 168}
# {'_id': 'Funeral Services & Cemeteries', 'count': 166}
# {'_id': 'Personal Shopping', 'count': 166}
# {'_id': 'Creperies', 'count': 165}
# {'_id': 'Roadside Assistance', 'count': 163}
# {'_id': 'Furniture Reupholstery', 'count': 163}
# {'_id': 'Snow Removal', 'count': 162}
# {'_id': 'Recycling Center', 'count': 161}
# {'_id': 'Television Service Providers', 'count': 159}
# {'_id': 'Home Window Tinting', 'count': 159}
# {'_id': 'Barre Classes', 'count': 158}
# {'_id': 'Fishing', 'count': 158}
# {'_id': 'Home Organization', 'count': 157}
# {'_id': 'Irish Pub', 'count': 157}
# {'_id': 'Lawn Services', 'count': 156}
# {'_id': 'Mass Media', 'count': 156}
# {'_id': 'Countertop Installation', 'count': 155}
# {'_id': 'Threading Services', 'count': 154}
# {'_id': 'Gun/Rifle Ranges', 'count': 153}
# {'_id': 'Pretzels', 'count': 153}
# {'_id': 'Rugs', 'count': 151}
# {'_id': 'Drywall Installation & Repair', 'count': 151}
# {'_id': 'Cheese Shops', 'count': 151}
# {'_id': 'Home & Rental Insurance', 'count': 150}
# {'_id': 'Wine Tasting Room', 'count': 149}
# {'_id': 'Animal Shelters', 'count': 149}
# {'_id': 'Cardio Classes', 'count': 149}
# {'_id': 'Walk-in Clinics', 'count': 148}
# {'_id': 'Comic Books', 'count': 148}
# {'_id': 'Refinishing Services', 'count': 148}
# {'_id': 'Life Insurance', 'count': 147}
# {'_id': 'Propane', 'count': 147}
# {'_id': 'Personal Injury Law', 'count': 146}
# {'_id': 'Do-It-Yourself Food', 'count': 145}
# {'_id': 'Internet Cafes', 'count': 143}
# {'_id': 'Vacation Rentals', 'count': 143}
# {'_id': 'Vinyl Records', 'count': 142}
# {'_id': 'Departments of Motor Vehicles', 'count': 140}
# {'_id': 'Leather Goods', 'count': 140}
# {'_id': 'Dim Sum', 'count': 140}
# {'_id': 'Tax Services', 'count': 139}
# {'_id': 'Cannabis Clinics', 'count': 139}
# {'_id': 'Social Clubs', 'count': 139}
# {'_id': 'Home Theatre Installation', 'count': 138}
# {'_id': 'Costumes', 'count': 137}
# {'_id': 'Historical Tours', 'count': 136}
# {'_id': 'Team Building Activities', 'count': 136}
# {'_id': 'Supernatural Readings', 'count': 136}
# {'_id': 'Public Transportation', 'count': 135}
# {'_id': 'Educational Services', 'count': 135}
# {'_id': 'Divorce & Family Law', 'count': 135}
# {'_id': 'Gay Bars', 'count': 135}
# {'_id': 'Plus Size Fashion', 'count': 133}
# {'_id': 'Carpet Installation', 'count': 133}
# {'_id': 'Boxing', 'count': 131}
# {'_id': 'Water Purification Services', 'count': 131}
# {'_id': 'Gold Buyers', 'count': 131}
# {'_id': 'Country Clubs', 'count': 131}
# {'_id': 'Modern European', 'count': 131}
# {'_id': 'Food Court', 'count': 130}
# {'_id': 'Boat Charters', 'count': 130}
# {'_id': 'Tanning Beds', 'count': 130}
# {'_id': 'Life Coach', 'count': 130}
# {'_id': 'Stadiums & Arenas', 'count': 130}
# {'_id': 'Cannabis Dispensaries', 'count': 128}
# {'_id': 'Screen Printing/T-Shirt Printing', 'count': 128}
# {'_id': 'Party Bus Rentals', 'count': 127}
# {'_id': 'Web Design', 'count': 127}
# {'_id': 'DJs', 'count': 127}
# {'_id': 'Marketing', 'count': 127}
# {'_id': 'Rafting/Kayaking', 'count': 126}
# {'_id': 'Accountants', 'count': 126}
# {'_id': 'Fireplace Services', 'count': 125}
# {'_id': 'German', 'count': 125}
# {'_id': 'Knitting Supplies', 'count': 124}
# {'_id': 'Podiatrists', 'count': 124}
# {'_id': 'Surgeons', 'count': 123}
# {'_id': 'Teeth Whitening', 'count': 122}
# {'_id': 'Cycling Classes', 'count': 122}
# {'_id': 'Beaches', 'count': 122}
# {'_id': 'Home Automation', 'count': 122}
# {'_id': 'University Housing', 'count': 122}
# {'_id': 'Mortgage Lenders', 'count': 122}
# {'_id': 'Airports', 'count': 122}
# {'_id': 'Data Recovery', 'count': 121}
# {'_id': 'Adult', 'count': 118}
# {'_id': 'Paint Stores', 'count': 118}
# {'_id': 'Airlines', 'count': 118}
# {'_id': 'Decks & Railing', 'count': 117}
# {'_id': 'Patisserie/Cake Shop', 'count': 117}
# {'_id': 'Septic Services', 'count': 117}
# {'_id': 'Pain Management', 'count': 116}
# {'_id': 'Solar Installation', 'count': 116}
# {'_id': 'Commercial Real Estate', 'count': 116}
# {'_id': 'Personal Chefs', 'count': 116}
# {'_id': 'Amateur Sports Teams', 'count': 116}
# {'_id': 'African', 'count': 115}
# {'_id': 'Casinos', 'count': 114}
# {'_id': 'Szechuan', 'count': 114}
# {'_id': 'Chimney Sweeps', 'count': 113}
# {'_id': 'Souvenir Shops', 'count': 113}
# {'_id': 'Home Health Care', 'count': 113}
# {'_id': 'Herbs & Spices', 'count': 112}
# {'_id': 'Skating Rinks', 'count': 111}
# {'_id': 'New Mexican Cuisine', 'count': 111}
# {'_id': 'Swimwear', 'count': 111}
# {'_id': 'Candle Stores', 'count': 110}
# {'_id': 'Wine Tours', 'count': 110}
# {'_id': 'RV Dealers', 'count': 109}
# {'_id': 'Paint & Sip', 'count': 109}
# {'_id': 'RV Repair', 'count': 108}
# {'_id': 'Pawn Shops', 'count': 108}
# {'_id': 'Filipino', 'count': 108}
# {'_id': 'Grout Services', 'count': 106}
# {'_id': 'Distilleries', 'count': 105}
# {'_id': 'Carpenters', 'count': 105}
# {'_id': 'Bespoke Clothing', 'count': 104}
# {'_id': 'Falafel', 'count': 103}
# {'_id': 'Plastic Surgeons', 'count': 103}
# {'_id': 'Utilities', 'count': 102}
# {'_id': 'Dance Schools', 'count': 102}
# {'_id': 'Donation Center', 'count': 101}
# {'_id': 'Video Game Stores', 'count': 100}
# {'_id': 'Walking Tours', 'count': 100}
# {'_id': 'Puerto Rican', 'count': 99}
# {'_id': 'Wildlife Control', 'count': 99}
# {'_id': 'Occupational Therapy', 'count': 99}
# {'_id': 'Meditation Centers', 'count': 99}
# {'_id': 'Fitness/Exercise Equipment', 'count': 98}
# {'_id': 'Waterproofing', 'count': 98}
# {'_id': 'Paddleboarding', 'count': 98}
# {'_id': 'Retirement Homes', 'count': 97}
# {'_id': 'Shutters', 'count': 97}
# {'_id': 'Comedy Clubs', 'count': 97}
# {'_id': 'Car Buyers', 'count': 96}
# {'_id': 'Mini Golf', 'count': 96}
# {'_id': 'Adult Education', 'count': 95}
# {'_id': 'Art Schools', 'count': 95}
# {'_id': 'Body Contouring', 'count': 94}
# {'_id': 'Cosmetology Schools', 'count': 93}
# {'_id': 'Emergency Rooms', 'count': 93}
# {'_id': 'Cantonese', 'count': 93}
# {'_id': 'Battery Stores', 'count': 93}
# {'_id': 'Campgrounds', 'count': 92}
# {'_id': 'Insulation Installation', 'count': 92}
# {'_id': 'Cooking Classes', 'count': 92}
# {'_id': 'Tattoo Removal', 'count': 92}
# {'_id': 'Photo Booth Rentals', 'count': 92}
# {'_id': 'Criminal Defense Law', 'count': 91}
# {'_id': 'Kebab', 'count': 90}
# {'_id': 'Uniforms', 'count': 90}
# {'_id': 'Advertising', 'count': 90}
# {'_id': 'Investing', 'count': 89}
# {'_id': 'Psychiatrists', 'count': 89}
# {'_id': 'Farms', 'count': 88}
# {'_id': 'Live/Raw Food', 'count': 88}
# {'_id': 'Spiritual Shop', 'count': 88}
# {'_id': 'Customized Merchandise', 'count': 88}
# {'_id': 'Video/Film Production', 'count': 87}
# {'_id': 'Motorcycle Gear', 'count': 87}
# {'_id': 'Tennis', 'count': 87}
# {'_id': 'Hunting & Fishing Supplies', 'count': 86}
# {'_id': 'Vehicle Wraps', 'count': 86}
# {'_id': 'Wigs', 'count': 86}
# {'_id': 'Donairs', 'count': 85}
# {'_id': 'Turkish', 'count': 85}
# {'_id': 'Whiskey Bars', 'count': 85}
# {'_id': 'RV Parks', 'count': 85}
# {'_id': 'Guitar Stores', 'count': 84}
# {'_id': 'Legal Services', 'count': 84}
# {'_id': 'Lebanese', 'count': 83}
# {'_id': 'Swimming Lessons/Schools', 'count': 83}
# {'_id': 'Peruvian', 'count': 82}
# {'_id': 'Outdoor Furniture Stores', 'count': 82}
# {'_id': 'Appraisal Services', 'count': 82}
# {'_id': 'Screen Printing', 'count': 81}
# {'_id': 'Employment Agencies', 'count': 81}
# {'_id': 'Indoor Playcentre', 'count': 81}
# {'_id': 'Radiologists', 'count': 80}
# {'_id': 'Auto Upholstery', 'count': 80}
# {'_id': 'Metal Fabricators', 'count': 80}
# {'_id': 'Kickboxing', 'count': 80}
# {'_id': 'Ear Nose & Throat', 'count': 79}
# {'_id': 'General Litigation', 'count': 79}
# {'_id': 'Registration Services', 'count': 78}
# {'_id': 'Boat Repair', 'count': 78}
# {'_id': 'Brazilian', 'count': 77}
# {'_id': 'Middle Schools & High Schools', 'count': 77}
# {'_id': 'Tabletop Games', 'count': 77}
# {'_id': 'Taiwanese', 'count': 77}
# {'_id': 'Cooking Schools', 'count': 76}
# {'_id': 'Print Media', 'count': 76}
# {'_id': 'Hot Pot', 'count': 75}
# {'_id': 'Embroidery & Crochet', 'count': 75}
# {'_id': 'Smokehouse', 'count': 75}
# {'_id': 'British', 'count': 75}
# {'_id': 'Pop-Up Restaurants', 'count': 75}
# {'_id': 'Estate Planning Law', 'count': 73}
# {'_id': 'Emergency Pet Hospital', 'count': 73}
# {'_id': 'Videographers', 'count': 73}
# {'_id': 'Gymnastics', 'count': 73}
# {'_id': 'Kosher', 'count': 73}
# {'_id': 'Trampoline Parks', 'count': 73}
# {'_id': 'Generator Installation/Repair', 'count': 72}
# {'_id': 'Tiki Bars', 'count': 72}
# {'_id': 'Golf Equipment', 'count': 72}
# {'_id': 'Orthotics', 'count': 71}
# {'_id': 'Bus Tours', 'count': 71}
# {'_id': 'Flea Markets', 'count': 70}
# {'_id': 'Pan Asian', 'count': 69}
# {'_id': 'Aquariums', 'count': 69}
# {'_id': 'DUI Law', 'count': 69}
# {'_id': 'Ethiopian', 'count': 67}
# {'_id': 'Horseback Riding', 'count': 67}
# {'_id': 'Colombian', 'count': 67}
# {'_id': 'Saunas', 'count': 66}
# {'_id': 'Allergists', 'count': 66}
# {'_id': 'Mountain Biking', 'count': 66}
# {'_id': 'Furniture Assembly', 'count': 65}
# {'_id': 'Patio Coverings', 'count': 65}
# {'_id': 'Commercial Truck Repair', 'count': 65}
# {'_id': 'Hydro-jetting', 'count': 65}
# {'_id': 'TV Mounting', 'count': 65}
# {'_id': 'Empanadas', 'count': 64}
# {'_id': 'Farming Equipment', 'count': 63}
# {'_id': 'Vocational & Technical School', 'count': 62}
# {'_id': 'Golf Lessons', 'count': 62}
# {'_id': 'Neurologist', 'count': 62}
# {'_id': 'Food Tours', 'count': 62}
# {'_id': 'Christmas Trees', 'count': 61}
# {'_id': 'Security Services', 'count': 61}
# {'_id': 'Boat Tours', 'count': 61}
# {'_id': 'Guest Houses', 'count': 61}
# {'_id': 'Salvadoran', 'count': 60}
# {'_id': 'Botanical Gardens', 'count': 60}
# {'_id': 'Perfume', 'count': 60}
# {'_id': 'Wholesalers', 'count': 60}
# {'_id': 'Driving Schools', 'count': 60}
# {'_id': 'Business Consulting', 'count': 60}
# {'_id': 'Climbing', 'count': 59}
# {'_id': 'Cultural Center', 'count': 59}
# {'_id': 'Shared Office Spaces', 'count': 59}
# {'_id': 'Hair Loss Centers', 'count': 59}
# {'_id': 'Alternative Medicine', 'count': 58}
# {'_id': 'Hats', 'count': 58}
# {'_id': 'Firearm Training', 'count': 58}
# {'_id': 'Stucco Services', 'count': 58}
# {'_id': 'Psychics', 'count': 58}
# {'_id': 'Professional Sports Teams', 'count': 57}
# {'_id': 'Environmental Testing', 'count': 56}
# {'_id': 'RV Rental', 'count': 56}
# {'_id': 'Auction Houses', 'count': 56}
# {'_id': 'Popcorn Shops', 'count': 55}
# {'_id': 'Tutoring Centers', 'count': 55}
# {'_id': 'Assisted Living Facilities', 'count': 55}
# {'_id': 'Business Law', 'count': 54}
# {'_id': 'Maternity Wear', 'count': 54}
# {'_id': 'Special Education', 'count': 54}
# {'_id': 'Cigar Bars', 'count': 53}
# {'_id': 'Town Car Service', 'count': 53}
# {'_id': 'Macarons', 'count': 53}
# {'_id': 'Furniture Repair', 'count': 53}
# {'_id': 'Axe Throwing', 'count': 53}
# {'_id': 'Sleep Specialists', 'count': 52}
# {'_id': 'Zoos', 'count': 52}
# {'_id': 'Sunglasses', 'count': 52}
# {'_id': 'Auto Security', 'count': 52}
# {'_id': 'Beverage Store', 'count': 52}
# {'_id': 'Home Network Installation', 'count': 51}
# {'_id': 'Cardiologists', 'count': 51}
# {'_id': 'Boat Dealers', 'count': 51}
# {'_id': 'Diving', 'count': 51}
# {'_id': 'Beer Tours', 'count': 51}
# {'_id': 'Bartenders', 'count': 50}
# {'_id': 'Challenge Courses', 'count': 50}
# {'_id': 'Float Spa', 'count': 50}
# {'_id': 'Environmental Abatement', 'count': 50}
# {'_id': 'Herbal Shops', 'count': 50}
# {'_id': 'Laser Tag', 'count': 50}
# {'_id': 'Brazilian Jiu-jitsu', 'count': 49}
# {'_id': 'Demolition Services', 'count': 49}
# {'_id': 'Employment Law', 'count': 49}
# {'_id': 'Moroccan', 'count': 49}
# {'_id': 'Kids Hair Salons', 'count': 49}
# {'_id': 'Estheticians', 'count': 48}
# {'_id': 'Venezuelan', 'count': 48}
# {'_id': 'Laotian', 'count': 48}
# {'_id': 'Haunted Houses', 'count': 48}
# {'_id': 'Hostels', 'count': 48}
# {'_id': 'Yelp Events', 'count': 48}
# {'_id': 'IV Hydration', 'count': 48}
# {'_id': 'Piano Bars', 'count': 48}
# {'_id': 'Service Stations', 'count': 48}
# {'_id': 'Acne Treatment', 'count': 47}
# {'_id': 'Piano Services', 'count': 47}
# {'_id': 'Brewing Supplies', 'count': 47}
# {'_id': 'Tui Na', 'count': 47}
# {'_id': 'Cafeteria', 'count': 47}
# {'_id': 'Art Museums', 'count': 47}
# {'_id': 'Skilled Nursing', 'count': 47}
# {'_id': 'Real Estate Law', 'count': 47}
# {'_id': 'Fertility', 'count': 47}
# {'_id': 'Brasseries', 'count': 47}
# {'_id': 'Radio Stations', 'count': 46}
# {'_id': 'Private Tutors', 'count': 46}
# {'_id': 'Leisure Centers', 'count': 45}
# {'_id': 'Aquarium Services', 'count': 45}
# {'_id': 'Blood & Plasma Donation Centers', 'count': 45}
# {'_id': 'Bankruptcy Law', 'count': 45}
# {'_id': 'Musicians', 'count': 45}
# {'_id': 'Midwives', 'count': 44}
# {'_id': 'Dominican', 'count': 44}
# {'_id': 'Skate Shops', 'count': 44}
# {'_id': 'Afghan', 'count': 44}
# {'_id': 'Home Staging', 'count': 44}
# {'_id': 'Tasting Classes', 'count': 44}
# {'_id': 'Car Inspectors', 'count': 44}
# {'_id': 'Officiants', 'count': 44}
# {'_id': 'Used Bookstore', 'count': 44}
# {'_id': 'Payroll Services', 'count': 44}
# {'_id': 'Kombucha', 'count': 43}
# {'_id': 'Aestheticians', 'count': 43}
# {'_id': 'Trailer Repair', 'count': 43}
# {'_id': 'Dental Hygienists', 'count': 43}
# {'_id': 'Pool & Billiards', 'count': 43}
# {'_id': 'Polish', 'count': 43}
# {'_id': 'Russian', 'count': 42}
# {'_id': 'Buses', 'count': 42}
# {'_id': 'Newspapers & Magazines', 'count': 42}
# {'_id': 'Foundation Repair', 'count': 42}
# {'_id': 'Firewood', 'count': 41}
# {'_id': 'Prosthodontists', 'count': 41}
# {'_id': 'Circuit Training Gyms', 'count': 40}
# {'_id': 'Holiday Decorations', 'count': 40}
# {'_id': 'Lighting Stores', 'count': 40}
# {'_id': 'Grilling Equipment', 'count': 40}
# {'_id': 'Ski & Snowboard Shops', 'count': 40}
# {'_id': 'Hypnosis/Hypnotherapy', 'count': 40}
# {'_id': 'Local Fish Stores', 'count': 40}
# {'_id': 'Persian/Iranian', 'count': 40}
# {'_id': 'Vehicle Shipping', 'count': 40}
# {'_id': 'Luggage', 'count': 40}
# {'_id': 'Basque', 'count': 39}
# {'_id': 'CSA', 'count': 39}
# {'_id': 'Farm Equipment Repair', 'count': 39}
# {'_id': 'Hospice', 'count': 39}
# {'_id': 'Day Camps', 'count': 39}
# {'_id': 'Gastroenterologist', 'count': 39}
# {'_id': 'Marinas', 'count': 39}
# {'_id': 'Roof Inspectors', 'count': 39}
# {'_id': 'Sugaring', 'count': 39}
# {'_id': 'Livestock Feed & Supply', 'count': 38}
# {'_id': '& Probates', 'count': 38}
# {'_id': 'Henna Artists', 'count': 38}
# {'_id': 'Teppanyaki', 'count': 38}
# {'_id': 'Excavation Services', 'count': 38}
# {'_id': 'Mobile Dent Repair', 'count': 38}
# {'_id': 'Check Cashing/Pay-day Loans', 'count': 38}
# {'_id': 'Trusts', 'count': 38}
# {'_id': 'Fire Protection Services', 'count': 38}
# {'_id': 'Wills', 'count': 38}
# {'_id': 'Go Karts', 'count': 38}
# {'_id': 'Osteopathic Physicians', 'count': 38}
# {'_id': 'Pet Transportation', 'count': 38}
# {'_id': 'Boudoir Photography', 'count': 37}
# {'_id': 'Trailer Dealers', 'count': 37}
# {'_id': 'Estate Liquidation', 'count': 37}
# {'_id': 'Travel Agents', 'count': 37}
# {'_id': 'Pet Hospice', 'count': 37}
# {'_id': 'Clothing Rental', 'count': 37}
# {'_id': 'Pet Cremation Services', 'count': 37}
# {'_id': 'Olive Oil', 'count': 37}
# {'_id': 'Paint-Your-Own Pottery', 'count': 37}
# {'_id': 'Cryotherapy', 'count': 37}
# {'_id': 'Audiologist', 'count': 36}
# {'_id': 'Race Tracks', 'count': 36}
# {'_id': 'Mongolian', 'count': 36}
# {'_id': 'Wedding Chapels', 'count': 36}
# {'_id': 'Archery', 'count': 36}
# {'_id': 'Train Stations', 'count': 36}
# {'_id': 'Recording & Rehearsal Studios', 'count': 36}
# {'_id': 'Arabic', 'count': 36}
# {'_id': 'Engraving', 'count': 35}
# {'_id': 'Shoe Shine', 'count': 35}
# {'_id': 'Dinner Theater', 'count': 35}
# {'_id': 'Workers Compensation Law', 'count': 35}
# {'_id': 'Police Departments', 'count': 35}
# {'_id': 'Rock Climbing', 'count': 35}
# {'_id': 'Awnings', 'count': 35}
# {'_id': 'Career Counseling', 'count': 35}
# {'_id': 'Scuba Diving', 'count': 34}
# {'_id': 'Dumpster Rental', 'count': 34}
# {'_id': 'Strip Clubs', 'count': 34}
# {'_id': 'Jet Skis', 'count': 34}
# {'_id': 'Argentine', 'count': 34}
# {'_id': 'Psychologists', 'count': 33}
# {'_id': 'Portuguese', 'count': 33}
# {'_id': 'Bistros', 'count': 33}
# {'_id': 'Paintball', 'count': 33}
# {'_id': 'Health Coach', 'count': 33}
# {'_id': 'Prenatal/Perinatal Care', 'count': 33}
# {'_id': 'Test Preparation', 'count': 33}
# {'_id': 'Community Centers', 'count': 32}
# {'_id': 'Spine Surgeons', 'count': 32}
# {'_id': 'Real Estate Photography', 'count': 32}
# {'_id': 'Balloon Services', 'count': 32}
# {'_id': 'Ethnic Grocery', 'count': 32}
# {'_id': 'Soccer', 'count': 32}
# {'_id': 'Urologists', 'count': 32}
# {'_id': 'Bike tours', 'count': 32}
# {'_id': 'Commercial Truck Dealers', 'count': 31}
# {'_id': 'Gemstones & Minerals', 'count': 31}
# {'_id': 'Knife Sharpening', 'count': 31}
# {'_id': 'Wine Tasting Classes', 'count': 31}
# {'_id': 'Pop-up Shops', 'count': 31}
# {'_id': 'Doulas', 'count': 31}
# {'_id': 'Television Stations', 'count': 31}
# {'_id': 'Malaysian', 'count': 30}
# {'_id': 'Delicatessen', 'count': 30}
# {'_id': 'Surfing', 'count': 30}
# {'_id': 'Self-defense Classes', 'count': 30}
# {'_id': 'Lakes', 'count': 30}
# {'_id': 'Speakeasies', 'count': 30}
# {'_id': 'Ticket Sales', 'count': 29}
# {'_id': 'Cremation Services', 'count': 29}
# {'_id': 'Pole Dancing Classes', 'count': 29}
# {'_id': 'Mobility Equipment Sales & Services', 'count': 29}
# {'_id': 'Water Delivery', 'count': 29}
# {'_id': 'Personal Assistants', 'count': 29}
# {'_id': 'Pumpkin Patches', 'count': 29}
# {'_id': 'Horse Boarding', 'count': 28}
# {'_id': 'Kitchen Supplies', 'count': 28}
# {'_id': 'Trailer Rental', 'count': 28}
# {'_id': 'Bookkeepers', 'count': 28}
# {'_id': 'Themed Cafes', 'count': 28}
# {'_id': 'Psychic Mediums', 'count': 28}
# {'_id': 'Airport Lounges', 'count': 28}
# {'_id': 'Eatertainment', 'count': 28}
# {'_id': 'Skate Parks', 'count': 28}
# {'_id': 'High Fidelity Audio Equipment', 'count': 27}
# {'_id': 'Hearing Aid Providers', 'count': 27}
# {'_id': 'Champagne Bars', 'count': 27}
# {'_id': 'Fondue', 'count': 27}
# {'_id': 'Condominiums', 'count': 27}
# {'_id': 'Lactation Services', 'count': 27}
# {'_id': 'Gunsmith', 'count': 27}
# {'_id': 'CPR Classes', 'count': 27}
# {'_id': 'Surf Shop', 'count': 26}
# {'_id': 'Poutineries', 'count': 26}
# {'_id': 'Cabaret', 'count': 26}
# {'_id': 'Magicians', 'count': 26}
# {'_id': 'Bar Crawl', 'count': 26}
# {'_id': 'Medical Transportation', 'count': 26}
# {'_id': 'Pick Your Own Farms', 'count': 26}
# {'_id': 'Machine & Tool Rental', 'count': 26}
# {'_id': 'Health Retreats', 'count': 25}
# {'_id': 'Virtual Reality Centers', 'count': 25}
# {'_id': 'Attraction Farms', 'count': 25}
# {'_id': 'Restaurant Supplies', 'count': 25}
# {'_id': 'Cideries', 'count': 25}
# {'_id': 'Batting Cages', 'count': 25}
# {'_id': 'Clock Repair', 'count': 25}
# {'_id': 'Endocrinologists', 'count': 25}
# {'_id': 'Medical Cannabis Referrals', 'count': 25}
# {'_id': 'Honduran', 'count': 24}
# {'_id': 'Reproductive Health Services', 'count': 24}
# {'_id': 'Shredding Services', 'count': 24}
# {'_id': 'Water Parks', 'count': 24}
# {'_id': 'Artificial Turf', 'count': 24}
# {'_id': 'Architects', 'count': 24}
# {'_id': 'Face Painting', 'count': 24}
# {'_id': 'Karate', 'count': 24}
# {'_id': 'Belgian', 'count': 24}
# {'_id': 'Medical Law', 'count': 23}
# {'_id': 'Childbirth Education', 'count': 23}
# {'_id': 'Religious Items', 'count': 23}
# {'_id': 'Indonesian', 'count': 23}
# {'_id': 'Trophy Shops', 'count': 23}
# {'_id': 'Addiction Medicine', 'count': 23}
# {'_id': 'Halotherapy', 'count': 23}
# {'_id': 'Bird Shops', 'count': 23}
# {'_id': 'Personal Care Services', 'count': 23}
# {'_id': 'Public Markets', 'count': 23}
# {'_id': 'Outdoor Power Equipment Services', 'count': 23}
# {'_id': 'Structural Engineers', 'count': 22}
# {'_id': 'Disc Golf', 'count': 22}
# {'_id': 'Oncologist', 'count': 22}
# {'_id': 'Shaved Snow', 'count': 22}
# {'_id': 'Races & Competitions', 'count': 22}
# {'_id': 'Pet Photography', 'count': 22}
# {'_id': 'Nurse Practitioner', 'count': 22}
# {'_id': 'Dietitians', 'count': 21}
# {'_id': 'Basketball Courts', 'count': 21}
# {'_id': 'House Sitters', 'count': 21}
# {'_id': 'Memory Care', 'count': 21}
# {'_id': 'Himalayan/Nepalese', 'count': 21}
# {'_id': 'Haitian', 'count': 20}
# {'_id': 'Muay Thai', 'count': 20}
# {'_id': 'Public Art', 'count': 20}
# {'_id': 'Massage Schools', 'count': 20}
# {'_id': 'Colonics', 'count': 20}
# {'_id': 'Well Drilling', 'count': 20}
# {'_id': 'Pulmonologist', 'count': 20}
# {'_id': 'Airport Terminals', 'count': 20}
# {'_id': 'Nanny Services', 'count': 20}
# {'_id': "Children's Museums", 'count': 20}
# {'_id': 'Tai Chi', 'count': 20}
# {'_id': 'Powder Coating', 'count': 19}
# {'_id': 'Immigration Law', 'count': 19}
# {'_id': 'Car Share Services', 'count': 19}
# {'_id': 'Motorsport Vehicle Repairs', 'count': 19}
# {'_id': 'Speech Therapists', 'count': 19}
# {'_id': 'Fingerprinting', 'count': 19}
# {'_id': 'Title Loans', 'count': 19}
# {'_id': 'Music Production Services', 'count': 19}
# {'_id': 'Aerial Fitness', 'count': 19}
# {'_id': 'Health Insurance Offices', 'count': 19}
# {'_id': 'Courthouses', 'count': 19}
# {'_id': 'Safe Stores', 'count': 18}
# {'_id': 'Flight Instruction', 'count': 18}
# {'_id': 'Party Bike Rentals', 'count': 18}
# {'_id': 'Cambodian', 'count': 18}
# {'_id': 'Motorcycle Rental', 'count': 18}
# {'_id': 'Honey', 'count': 18}
# {'_id': 'Burmese', 'count': 18}
# {'_id': 'Ukrainian', 'count': 18}
# {'_id': 'Valet Services', 'count': 18}
# {'_id': 'Art Tours', 'count': 18}
# {'_id': 'Vacation Rental Agents', 'count': 17}
# {'_id': 'Trinidadian', 'count': 17}
# {'_id': 'Skydiving', 'count': 17}
# {'_id': 'Concierge Medicine', 'count': 17}
# {'_id': 'Wallpapering', 'count': 17}
# {'_id': 'Talent Agencies', 'count': 17}
# {'_id': 'Shanghainese', 'count': 17}
# {'_id': 'Hydrotherapy', 'count': 16}
# {'_id': 'Architectural Tours', 'count': 16}
# {'_id': 'Dive Shops', 'count': 16}
# {'_id': 'Passport & Visa Services', 'count': 16}
# {'_id': 'Egyptian', 'count': 16}
# {'_id': 'Lice Services', 'count': 16}
# {'_id': 'Izakaya', 'count': 16}
# {'_id': 'Ultrasound Imaging Centers', 'count': 16}
# {'_id': 'Sicilian', 'count': 16}
# {'_id': 'Holistic Animal Care', 'count': 16}
# {'_id': 'Parenting Classes', 'count': 15}
# {'_id': 'Emergency Medicine', 'count': 15}
# {'_id': 'Pet Breeders', 'count': 15}
# {'_id': 'Armenian', 'count': 15}
# {'_id': 'Holiday Decorating Services', 'count': 15}
# {'_id': 'Religious Schools', 'count': 15}
# {'_id': 'Crane Services', 'count': 15}
# {'_id': 'Installment Loans', 'count': 15}
# {'_id': 'Bounce House Rentals', 'count': 15}
# {'_id': 'Editorial Services', 'count': 14}
# {'_id': 'Debt Relief Services', 'count': 14}
# {'_id': 'Baseball Fields', 'count': 14}
# {'_id': 'Golf Equipment Shops', 'count': 14}
# {'_id': 'Vascular Medicine', 'count': 14}
# {'_id': 'Car Brokers', 'count': 14}
# {'_id': 'Pancakes', 'count': 14}
# {'_id': 'Solar Panel Cleaning', 'count': 14}
# {'_id': 'Snorkeling', 'count': 14}
# {'_id': 'Software Development', 'count': 14}
# {'_id': 'First Aid Classes', 'count': 14}
# {'_id': 'Private Investigation', 'count': 14}
# {'_id': 'Bangladeshi', 'count': 14}
# {'_id': 'Rolfing', 'count': 14}
# {'_id': 'Home Energy Auditors', 'count': 14}
# {'_id': 'Dance Wear', 'count': 14}
# {'_id': 'Motorcycle Parts & Supplies', 'count': 13}
# {'_id': 'Rheumatologists', 'count': 13}
# {'_id': 'Reptile Shops', 'count': 13}
# {'_id': 'Scooter Rentals', 'count': 13}
# {'_id': 'Business Financing', 'count': 13}
# {'_id': 'Japanese Curry', 'count': 13}
# {'_id': 'Preventive Medicine', 'count': 13}
# {'_id': 'Taekwondo', 'count': 13}
# {'_id': 'Australian', 'count': 13}
# {'_id': 'Matchmakers', 'count': 13}
# {'_id': 'Ski Resorts', 'count': 13}
# {'_id': 'Montessori Schools', 'count': 13}
# {'_id': 'Sailing', 'count': 13}
# {'_id': 'Commissioned Artists', 'count': 13}
# {'_id': 'Tableware', 'count': 13}
# {'_id': 'Tubing', 'count': 12}
# {'_id': 'Hot Air Balloons', 'count': 12}
# {'_id': 'Safety Equipment', 'count': 12}
# {'_id': 'Piano Stores', 'count': 12}
# {'_id': 'Motorsport Vehicle Dealers', 'count': 12}
# {'_id': 'ATV Rentals/Tours', 'count': 12}
# {'_id': 'Homeowner Association', 'count': 12}
# {'_id': 'Food Banks', 'count': 12}
# {'_id': 'Social Security Law', 'count': 12}
# {'_id': 'Qi Gong', 'count': 12}
# {'_id': 'Aerial Tours', 'count': 12}
# {'_id': 'Audio/Visual Equipment Rental', 'count': 12}
# {'_id': 'Mobile Home Parks', 'count': 12}
# {'_id': 'Ziplining', 'count': 12}
# {'_id': 'Beach Equipment Rentals', 'count': 12}
# {'_id': 'Anesthesiologists', 'count': 12}
# {'_id': 'Synagogues', 'count': 12}
# {'_id': 'Water Stores', 'count': 12}
# {'_id': 'Private Schools', 'count': 12}
# {'_id': 'Public Relations', 'count': 11}
# {'_id': 'Country Dance Halls', 'count': 11}
# {'_id': 'Hockey Equipment', 'count': 11}
# {'_id': 'Traffic Ticketing Law', 'count': 11}
# {'_id': 'Scandinavian', 'count': 11}
# {'_id': 'Prosthetics', 'count': 11}
# {'_id': 'Trains', 'count': 11}
# {'_id': 'Military Surplus', 'count': 11}
# {'_id': 'Photography Classes', 'count': 11}
# {'_id': 'Tax Law', 'count': 11}
# {'_id': 'Car Auctions', 'count': 11}
# {'_id': 'Diamond Buyers', 'count': 11}
# {'_id': 'Home Developers', 'count': 11}
# {'_id': 'Hybrid Car Repair', 'count': 10}
# {'_id': 'Ayurveda', 'count': 10}
# {'_id': 'Machine Shops', 'count': 10}
# {'_id': 'Junkyards', 'count': 10}
# {'_id': 'Glass Blowing', 'count': 10}
# {'_id': 'Pet Waste Removal', 'count': 10}
# {'_id': 'Bartending Schools', 'count': 10}
# {'_id': 'Grill Services', 'count': 10}
# {'_id': 'Drive-Thru Bars', 'count': 10}
# {'_id': 'Bail Bondsmen', 'count': 10}
# {'_id': 'Clowns', 'count': 10}
# {'_id': 'Language Schools', 'count': 10}
# {'_id': 'Art Restoration', 'count': 10}
# {'_id': 'Art Space Rentals', 'count': 10}
# {'_id': 'Rest Stops', 'count': 10}
# {'_id': 'Horse Racing', 'count': 10}
# {'_id': 'Iberian', 'count': 10}
# {'_id': 'Boat Parts & Supplies', 'count': 10}
# {'_id': 'Opera & Ballet', 'count': 10}
# {'_id': 'Astrologers', 'count': 9}
# {'_id': 'Public Adjusters', 'count': 9}
# {'_id': 'Pet Insurance', 'count': 9}
# {'_id': 'Translation Services', 'count': 9}
# {'_id': 'Visitor Centers', 'count': 9}
# {'_id': 'Hazardous Waste Disposal', 'count': 9}
# {'_id': 'Fireworks', 'count': 9}
# {'_id': 'Digitizing Services', 'count': 9}
# {'_id': 'Teacher Supplies', 'count': 9}
# {'_id': 'Mediators', 'count': 9}
# {'_id': 'Syrian', 'count': 9}
# {'_id': 'Parasailing', 'count': 9}
# {'_id': 'Scavenger Hunts', 'count': 9}
# {'_id': 'Singaporean', 'count': 9}
# {'_id': 'EV Charging Stations', 'count': 9}
# {'_id': 'Hydroponics', 'count': 9}
# {'_id': 'Party Characters', 'count': 9}
# {'_id': 'Horse Equipment Shops', 'count': 8}
# {'_id': 'Mobile Home Dealers', 'count': 8}
# {'_id': 'Bookbinding', 'count': 8}
# {'_id': 'Airsoft', 'count': 8}
# {'_id': 'Uzbek', 'count': 8}
# {'_id': 'Golf Cart Rentals', 'count': 8}
# {'_id': 'Animal Physical Therapy', 'count': 8}
# {'_id': 'Drive-In Theater', 'count': 8}
# {'_id': 'Scooter Tours', 'count': 8}
# {'_id': 'Cannabis Collective', 'count': 8}
# {'_id': 'Retina Specialists', 'count': 8}
# {'_id': 'Buddhist Temples', 'count': 8}
# {'_id': 'Petting Zoos', 'count': 8}
# {'_id': 'Furniture Rental', 'count': 8}
# {'_id': 'Surf Schools', 'count': 8}
# {'_id': 'Caricatures', 'count': 8}
# {'_id': 'Flowers', 'count': 8}
# {'_id': 'Coffeeshops', 'count': 8}
# {'_id': 'Golf Cart Dealers', 'count': 7}
# {'_id': 'Taxidermy', 'count': 7}
# {'_id': 'Free Diving', 'count': 7}
# {'_id': 'Process Servers', 'count': 7}
# {'_id': 'Backflow Services', 'count': 7}
# {'_id': 'Whale Watching Tours', 'count': 7}
# {'_id': 'Elder Care Planning', 'count': 7}
# {'_id': 'Sandblasting', 'count': 7}
# {'_id': 'Behavior Analysts', 'count': 7}
# {'_id': 'Mobile Home Repair', 'count': 7}
# {'_id': 'Observatories', 'count': 7}
# {'_id': 'Tuscan', 'count': 7}
# {'_id': 'Ranches', 'count': 7}
# {'_id': 'Planetarium', 'count': 7}
# {'_id': 'International', 'count': 7}
# {'_id': 'Contract Law', 'count': 7}
# {'_id': 'LAN Centers', 'count': 7}
# {'_id': 'Oxygen Bars', 'count': 7}
# {'_id': 'Traditional Clothing', 'count': 7}
# {'_id': 'Czech', 'count': 6}
# {'_id': 'Bike Sharing', 'count': 6}
# {'_id': 'Senior Centers', 'count': 6}
# {'_id': 'Senegalese', 'count': 6}
# {'_id': 'Carpet Dyeing', 'count': 6}
# {'_id': 'Placenta Encapsulations', 'count': 6}
# {'_id': 'Bus Rental', 'count': 6}
# {'_id': 'Nicaraguan', 'count': 6}
# {'_id': 'South African', 'count': 6}
# {'_id': 'Indoor Landscaping', 'count': 6}
# {'_id': 'Hungarian', 'count': 6}
# {'_id': 'Hong Kong Style Cafe', 'count': 6}
# {'_id': 'Striptease Dancers', 'count': 6}
# {'_id': 'Undersea/Hyperbaric Medicine', 'count': 5}
# {'_id': 'Meaderies', 'count': 5}
# {'_id': 'Land Surveying', 'count': 5}
# {'_id': 'Bicycles', 'count': 5}
# {'_id': 'Neurotologists', 'count': 5}
# {'_id': 'Club Crawl', 'count': 5}
# {'_id': 'Billing Services', 'count': 5}
# {'_id': 'Private Jet Charter', 'count': 5}
# {'_id': 'Traffic Schools', 'count': 5}
# {'_id': 'Austrian', 'count': 5}
# {'_id': 'Spin Classes', 'count': 5}
# {'_id': 'Scottish', 'count': 5}
# {'_id': '3D Printing', 'count': 5}
# {'_id': 'Drones', 'count': 5}
# {'_id': 'Coffee & Tea Supplies', 'count': 5}
# {'_id': 'Luggage Storage', 'count': 5}
# {'_id': 'Mortuary Services', 'count': 5}
# {'_id': 'Immunodermatologists', 'count': 5}
# {'_id': 'Drama Schools', 'count': 4}
# {'_id': 'Sports Betting', 'count': 4}
# {'_id': 'Chinese Martial Arts', 'count': 4}
# {'_id': 'Pedicabs', 'count': 4}
# {'_id': 'Fur Clothing', 'count': 4}
# {'_id': 'Tenant and Eviction Law', 'count': 4}
# {'_id': 'Disability Law', 'count': 4}
# {'_id': 'Sardinian', 'count': 4}
# {'_id': 'Bus Stations', 'count': 4}
# {'_id': 'Bingo Halls', 'count': 4}
# {'_id': 'Duplication Services', 'count': 4}
# {'_id': 'Proctologists', 'count': 4}
# {'_id': 'Apartment Agents', 'count': 4}
# {'_id': 'Aircraft Repairs', 'count': 4}
# {'_id': 'DIY Auto Shop', 'count': 4}
# {'_id': 'Currency Exchange', 'count': 4}
# {'_id': 'Product Design', 'count': 4}
# {'_id': 'Gerontologists', 'count': 4}
# {'_id': 'Georgian', 'count': 4}
# {'_id': 'Adoption Services', 'count': 4}
# {'_id': 'Trivia Hosts', 'count': 4}
# {'_id': 'Portable Toilet Services', 'count': 4}
# {'_id': 'Hang Gliding', 'count': 4}
# {'_id': 'Ethical Grocery', 'count': 4}
# {'_id': 'Hindu Temples', 'count': 4}
# {'_id': 'Racing Experience', 'count': 4}
# {'_id': 'Biohazard Cleanup', 'count': 4}
# {'_id': 'Phlebologists', 'count': 4}
# {'_id': 'Sex Therapists', 'count': 4}
# {'_id': 'Skiing', 'count': 3}
# {'_id': 'Supper Clubs', 'count': 3}
# {'_id': 'Carousels', 'count': 3}
# {'_id': 'Elder Law', 'count': 3}
# {'_id': 'Embassy', 'count': 3}
# {'_id': 'Neuropathologists', 'count': 3}
# {'_id': 'Nursing Schools', 'count': 3}
# {'_id': 'Sheds & Outdoor Storage', 'count': 3}
# {'_id': 'Ice Delivery', 'count': 3}
# {'_id': 'Sri Lankan', 'count': 3}
# {'_id': 'Badminton', 'count': 3}
# {'_id': 'Flyboarding', 'count': 3}
# {'_id': 'Community Gardens', 'count': 3}
# {'_id': 'Crisis Pregnancy Centers', 'count': 3}
# {'_id': 'College Counseling', 'count': 3}
# {'_id': 'Nudist', 'count': 3}
# {'_id': 'Consumer Law', 'count': 3}
# {'_id': 'Playsets', 'count': 3}
# {'_id': 'Ferries', 'count': 3}
# {'_id': 'Childproofing', 'count': 3}
# {'_id': 'Squash', 'count': 3}
# {'_id': 'IP & Internet Law', 'count': 3}
# {'_id': 'Game Truck Rental', 'count': 3}
# {'_id': 'Electricity Suppliers', 'count': 3}
# {'_id': 'Bike Repair', 'count': 3}
# {'_id': 'Unofficial Yelp Events', 'count': 3}
# {'_id': 'Jails & Prisons', 'count': 3}
# {'_id': 'Elevator Services', 'count': 3}
# {'_id': 'Oriental', 'count': 3}
# {'_id': 'Municipality', 'count': 3}
# {'_id': 'Somali', 'count': 2}
# {'_id': 'Hotel bar', 'count': 2}
# {'_id': 'Silent Disco', 'count': 2}
# {'_id': 'Bicycle Paths', 'count': 2}
# {'_id': 'Cannabis Tours', 'count': 2}
# {'_id': 'Cheerleading', 'count': 2}
# {'_id': 'Waldorf Schools', 'count': 2}
# {'_id': 'Rodeo', 'count': 2}
# {'_id': 'Otologists', 'count': 2}
# {'_id': 'Sports Psychologists', 'count': 2}
# {'_id': 'Infectious Disease Specialists', 'count': 2}
# {'_id': 'Bocce Ball', 'count': 2}
# {'_id': 'Kitchen Incubators', 'count': 2}
# {'_id': 'Dumplings', 'count': 2}
# {'_id': 'Vocal Coach', 'count': 2}
# {'_id': 'Homeless Shelters', 'count': 2}
# {'_id': 'Art Consultants', 'count': 2}
# {'_id': 'Hakka', 'count': 2}
# {'_id': 'Sledding', 'count': 2}
# {'_id': 'Kiteboarding', 'count': 2}
# {'_id': 'Nephrologists', 'count': 2}
# {'_id': 'Fire Departments', 'count': 2}
# {'_id': 'Eastern European', 'count': 2}
# {'_id': 'Mosques', 'count': 2}
# {'_id': 'Bike Shop', 'count': 2}
# {'_id': 'Sauna Installation & Repair', 'count': 2}
# {'_id': 'Ski Schools', 'count': 2}
# {'_id': 'Cheese Tasting Classes', 'count': 2}
# {'_id': 'Experiences', 'count': 2}
# {'_id': 'Israeli', 'count': 2}
# {'_id': 'General Festivals', 'count': 2}
# {'_id': 'Calligraphy', 'count': 2}
# {'_id': 'Art Installation', 'count': 2}
# {'_id': 'Veterans Organizations', 'count': 2}
# {'_id': 'Concept Shops', 'count': 2}
# {'_id': 'Outdoor Movies', 'count': 2}
# {'_id': 'Metal Detector Services', 'count': 1}
# {'_id': 'Paragliding', 'count': 1}
# {'_id': 'Foot Care', 'count': 1}
# {'_id': 'Karaoke Rental', 'count': 1}
# {'_id': 'Circus Schools', 'count': 1}
# {'_id': 'Serbo Croatian', 'count': 1}
# {'_id': 'Conveyor Belt Sushi', 'count': 1}
# {'_id': 'Hepatologists', 'count': 1}
# {'_id': 'Housing Cooperatives', 'count': 1}
# {'_id': 'Tonkatsu', 'count': 1}
# {'_id': 'Roman', 'count': 1}
# {'_id': 'Aircraft Dealers', 'count': 1}
# {'_id': 'Dart Arenas', 'count': 1}
# {'_id': 'Water Suppliers', 'count': 1}
# {'_id': 'Bike Parking', 'count': 1}
# {'_id': 'Fuel Docks', 'count': 1}
# {'_id': 'Props', 'count': 1}
# {'_id': 'Wildlife Hunting Ranges', 'count': 1}
# {'_id': 'Makerspaces', 'count': 1}
# {'_id': 'Kiosk', 'count': 1}
# {'_id': 'Dialysis Clinics', 'count': 1}
# {'_id': 'Sport Equipment Hire', 'count': 1}
# {'_id': 'Guamanian', 'count': 1}
# {'_id': 'Halfway Houses', 'count': 1}
# {'_id': 'Osteopaths', 'count': 1}
# {'_id': 'Fencing Clubs', 'count': 1}
# {'_id': 'Hainan', 'count': 1}
# {'_id': 'Faith-based Crisis Pregnancy Centers', 'count': 1}
# {'_id': 'Interlock Systems', 'count': 1}
# {'_id': 'Storefront Clinics', 'count': 1}
# {'_id': 'Pickleball', 'count': 1}
# {'_id': 'Bubble Soccer', 'count': 1}
# {'_id': 'Pathologists', 'count': 1}
# {'_id': 'DUI Schools', 'count': 1}
# {'_id': 'Ceremonial Clothing', 'count': 1}
# {'_id': 'Natural Gas Suppliers', 'count': 1}
# {'_id': 'Town Hall', 'count': 1}
# {'_id': 'Parklets', 'count': 1}
# {'_id': 'Aviation Services', 'count': 1}
# {'_id': 'Mohels', 'count': 1}
# {'_id': 'Beach Bars', 'count': 1}
# {'_id': 'Cucina campana', 'count': 1}
# {'_id': 'Hospitalists', 'count': 1}
# {'_id': 'Sperm Clinic', 'count': 1}
# {'_id': 'Calabrian', 'count': 1}
# {'_id': 'Donburi', 'count': 1}
# {'_id': 'Beer Hall', 'count': 1}
# {'_id': 'Stonemasons', 'count': 1}
# {'_id': 'Parent Cafes', 'count': 1}
# {'_id': 'Lahmacun', 'count': 1}
# {'_id': 'Pita', 'count': 1}
# {'_id': 'Animal Assisted Therapy', 'count': 1}
# {'_id': 'Vermouth Bars', 'count': 1}
# {'_id': 'Trade Fairs', 'count': 1}
# {'_id': 'Fuzhou', 'count': 1}
# {'_id': 'Patent Law', 'count': 1}

# %%
# Filtrar solo por la categoría "Restaurants"
restaurant_category = "Restaurants"

# Pipeline para analizar todas las categorías disponibles
print("\nAnalizando categorías disponibles...")
pipeline_categories = [
    {"$match": {"categories": {"$exists": True, "$ne": None}}},
    {"$project": {"categories": {"$split": ["$categories", ", "]}}},
    {"$unwind": "$categories"},
    {"$group": {"_id": "$categories", "count": {"$sum": 1}}},
    {"$sort": {"count": -1}},
    {"$limit": 50}  # Limitar a las top 50 categorías
]

print("Top 50 categorías más comunes:")
categories_cursor = db["businesses"].aggregate(pipeline_categories)
for i, cat in enumerate(categories_cursor, 1):
    print(f"{i:2d}. {cat['_id']}: {cat['count']:,} negocios")

# Contar específicamente cuántos negocios son restaurantes
restaurant_count = db["businesses"].count_documents({
    "categories": {"$regex": f"\\b{restaurant_category}\\b"}
})

print(f"Total de restaurantes encontrados: {restaurant_count:,}")
# Out:
# Analizando categorías disponibles...
# Top 50 categorías más comunes:
#  1. Restaurants: 52,268 negocios
#  2. Food: 27,781 negocios
#  3. Shopping: 24,395 negocios
#  4. Home Services: 14,356 negocios
#  5. Beauty & Spas: 14,292 negocios
#  6. Nightlife: 12,281 negocios
#  7. Health & Medical: 11,890 negocios
#  8. Local Services: 11,198 negocios
#  9. Bars: 11,065 negocios
# 10. Automotive: 10,773 negocios
# 11. Event Planning & Services: 9,895 negocios
# 12. Sandwiches: 8,366 negocios
# 13. American (Traditional): 8,139 negocios
# 14. Active Life: 7,687 negocios
# 15. Pizza: 7,093 negocios
# 16. Coffee & Tea: 6,703 negocios
# 17. Fast Food: 6,472 negocios
# 18. Breakfast & Brunch: 6,239 negocios
# 19. American (New): 6,097 negocios
# 20. Hotels & Travel: 5,857 negocios
# 21. Home & Garden: 5,799 negocios
# 22. Fashion: 5,739 negocios
# 23. Burgers: 5,636 negocios
# 24. Arts & Entertainment: 5,434 negocios
# 25. Auto Repair: 5,433 negocios
# 26. Hair Salons: 5,046 negocios
# 27. Nail Salons: 4,621 negocios
# 28. Mexican: 4,600 negocios
# 29. Italian: 4,573 negocios
# 30. Specialty Food: 4,233 negocios
# 31. Doctors: 3,763 negocios
# 32. Pets: 3,758 negocios
# 33. Real Estate: 3,577 negocios
# 34. Seafood: 3,539 negocios
# 35. Fitness & Instruction: 3,293 negocios
# 36. Professional Services: 3,270 negocios
# 37. Hair Removal: 3,239 negocios
# 38. Desserts: 3,186 negocios
# 39. Chinese: 3,169 negocios
# 40. Bakeries: 3,150 negocios
# 41. Grocery: 3,139 negocios
# 42. Salad: 3,064 negocios
# 43. Hotels: 2,977 negocios
# 44. Chicken Wings: 2,966 negocios
# 45. Cafes: 2,756 negocios
# 46. Ice Cream & Frozen Yogurt: 2,657 negocios
# 47. Caterers: 2,645 negocios
# 48. Pet Services: 2,626 negocios
# 49. Dentists: 2,528 negocios
# 50. Skin Care: 2,498 negocios
# Total de restaurantes encontrados: 52,268

# %% [markdown]
# ## 7. Optimización con Índices
#
# Para mejorar el rendimiento de las consultas que haremos después, creamos índices en los campos que más usaremos:
#
# ### Índices creados:
# - **`categories` en businesses**: Para filtrar por tipo de negocio rápidamente
# - **`business_id` en businesses**: Para búsquedas por ID de negocio
# - **`business_id` en reviews**: Para conectar reviews con restaurantes eficientemente
#
# ### ¿Por qué son importantes los índices?
# Sin índices, MongoDB tiene que revisar todos los documentos uno por uno para encontrar lo que buscas. Con índices, las búsquedas son mucho más rápidas, especialmente cuando tenemos millones de documentos.
#
# Crear estos índices ahora nos ahorrará mucho tiempo en las operaciones siguientes.

# %%
# Crear índices para optimizar las consultas
print("\nCreando índices para optimizar consultas...")
try:
    db["businesses"].create_index("categories")
    db["businesses"].create_index("business_id")
    db["reviews"].create_index("business_id")
    print("Indices creados exitosamente")
except Exception as e:
    print(f"Error creando índices: {e}")
# Out:
# Creando índices para optimizar consultas...
# Indices creados exitosamente

# %% [markdown]
# ## 8. Extracción de Restaurantes con Reviews
#
# Esta es la parte principal del proceso donde obtenemos todos los restaurantes junto con sus reseñas.
#
# ### ¿Por qué no usar un JOIN directo en MongoDB?
# Los JOINs tradicionales en MongoDB pueden ser muy lentos cuando tenemos:
# - ~52,000 restaurantes
# - ~5,000,000 reviews
# - Conexión a MongoDB Atlas por internet
# - Operaciones que pueden tomar 20-40 minutos y fallar por timeouts
#
# ### Nuestra solución: Queries separadas + JOIN local
# En lugar de un JOIN complejo en MongoDB, hacemos el proceso en pasos simples:
#
# 1. **Paso 1**: Obtenemos todos los restaurantes (rápido)
# 2. **Paso 2**: Obtenemos las reviews de esos restaurantes en lotes (controlado)
# 3. **Paso 3**: Unimos todo usando pandas en memoria local (súper rápido)
#
# Esta estrategia reduce el tiempo de ~30 minutos a ~5 minutos y es mucho más confiable.

# %% [markdown]
# ### Paso 1: Obtener datos de restaurantes
#
# Extraemos todos los negocios que tienen "Restaurants" en sus categorías.
#
# **Campos que obtenemos:**
# - **Información básica**: business_id, name, categories
# - **Ubicación**: address, city, state, postal_code, latitude, longitude
# - **Métricas**: stars, review_count, is_open
# - **Extras**: attributes, hours
#
# **Optimización importante:** Solo transferimos los campos que necesitamos, excluyendo el `_id` de MongoDB y otros campos innecesarios. Esto hace la transferencia más rápida.
#
# El resultado es un DataFrame de pandas con información de todos los restaurantes.

# %%
start_time = time.time()

# Obtener datos de restaurantes
print("Paso 1: Obteniendo datos de restaurantes...")


restaurants_cursor = db["businesses"].find(
    {"categories": {"$regex": f"\\b{restaurant_category}\\b"}},
    {
        "_id": 0,  # Excluir _id de MongoDB
        "business_id": 1, 
        "name": 1, 
        "categories": 1, 
        "address": 1,
        "city": 1, 
        "state": 1, 
        "postal_code": 1,
        "latitude": 1,      
        "longitude": 1,    
        "stars": 1,         
        "review_count": 1,  
        "is_open": 1,       
        "attributes": 1,    
        "hours": 1          
    }
)

# Convertir cursor a lista con seguimiento de progreso
restaurants_list = []
with tqdm(desc="Cargando restaurantes", unit="restaurants") as pbar:
    for restaurant in restaurants_cursor:
        restaurants_list.append(restaurant)
        pbar.update(1)
restaurants_df = pd.DataFrame(restaurants_list)

step1_time = time.time() - start_time
print(f"Restaurantes obtenidos: {len(restaurants_df):,} en {step1_time:.1f}s")
# Out:
# Paso 1: Obteniendo datos de restaurantes...
# Cargando restaurantes: 52268restaurants [00:06, 7512.93restaurants/s]
# Restaurantes obtenidos: 52,268 en 7.0s

# %% [markdown]
# ### Paso 2: Obtener reviews de esos restaurantes
#
# Ahora obtenemos todas las reviews de los restaurantes que encontramos en el paso anterior.
#
# **¿Por qué procesamos en lotes?**
# - Tenemos ~52,000 restaurantes que pueden tener millones de reviews
# - Cada lote procesa 5,000 restaurantes a la vez
# - Esto evita problemas de memoria y timeouts de red
# - Podemos ver el progreso y recuperarnos si algo falla
#
# **Campos de review que obtenemos:**
# - **Identificadores**: business_id, review_id, user_id
# - **Contenido principal**: text, stars, date
# - **Métricas de utilidad**: useful, funny, cool
#
# **Progreso:** Vemos el avance lote por lote para saber cómo va el proceso.
#
# Al final tenemos todas las reviews de todos nuestros restaurantes.

# %%
# Obtener reviews de esos restaurantes
print("Paso 2: Obteniendo reviews de esos restaurantes...")

restaurant_ids = restaurants_df['business_id'].tolist()

# Procesar en lotes para evitar límites de MongoDB
batch_size = 5000  # Tamaño de lote
all_reviews = []

total_batches = (len(restaurant_ids) + batch_size - 1) // batch_size

# Usar context manager para procesamiento por lotes
with tqdm(range(0, len(restaurant_ids), batch_size), desc="Procesando lotes", total=total_batches, unit="lotes") as batch_progress:
    for i in batch_progress:
        batch_ids = restaurant_ids[i:i + batch_size]
        
        reviews_cursor = db["reviews"].find(
            {"business_id": {"$in": batch_ids}},
            {
                "_id": 0,  # Excluir _id de MongoDB
                "business_id": 1, 
                "review_id": 1, 
                "user_id": 1,
                "stars": 1, 
                "date": 1, 
                "text": 1, 
                "useful": 1,
                "funny": 1, 
                "cool": 1
            }
        )
        
        batch_reviews = list(reviews_cursor)
        all_reviews.extend(batch_reviews)

reviews_df = pd.DataFrame(all_reviews)

step2_time = time.time() - start_time - step1_time
print(f"Reviews obtenidos: {len(reviews_df):,} en {step2_time:.1f}s")
# Out:
# Paso 2: Obteniendo reviews de esos restaurantes...
# Procesando lotes: 100%|██████████| 11/11 [46:11<00:00, 251.94s/lotes]
# Reviews obtenidos: 4,724,471 en 2776.1s

# %% [markdown]
# ### Paso 3: Guardar archivos separados de business y reviews
#
# Antes de hacer el JOIN, guardamos los DataFrames de restaurantes y reviews en archivos separados para tener flexibilidad en el análisis.
#
# **Archivos generados:**
# - **`businesses.json`**: Contiene todos los restaurantes filtrados con sus datos completos
# - **`reviews.json`**: Contiene todas las reviews de esos restaurantes
#
# **¿Por qué guardar archivos separados?**
# - **Flexibilidad**: Permite trabajar con restaurantes y reviews por separado
# - **Análisis específicos**: Facilita análisis que requieren solo una parte de los datos
# - **Debugging**: Ayuda a identificar problemas en cada conjunto de datos
# - **Reutilización**: Los archivos pueden usarse en otros notebooks sin reprocesar
#
# **Formato de los archivos:**
# - JSON con indentación para fácil lectura
# - Encoding UTF-8 para caracteres especiales
# - Estructura consistente con el archivo final

# %%
# Guardar archivos separados de business y reviews
print("Paso 3: Guardando archivos separados de business y reviews...")

# Crear directorio si no existe
os.makedirs("../data", exist_ok=True)

# Guardar DataFrame de restaurantes
businesses_file = "../data/processed/businesses.json"
restaurants_list = restaurants_df.to_dict('records')
with open(businesses_file, "w", encoding="utf-8") as f:
    json.dump(restaurants_list, f, ensure_ascii=False, indent=2, default=str)
print(f"Archivo de restaurantes guardado: {businesses_file}")

# Guardar DataFrame de reviews
reviews_file = "../data/processed/reviews.json"
reviews_list = reviews_df.to_dict('records')
with open(reviews_file, "w", encoding="utf-8") as f:
    json.dump(reviews_list, f, ensure_ascii=False, indent=2, default=str)
print(f"Archivo de reviews guardado: {reviews_file}")
# Out:
# Paso 3: Guardando archivos separados de business y reviews...
# Archivo de restaurantes guardado: ../data/processed/businesses.json
# Archivo de reviews guardado: ../data/processed/reviews.json

# %% [markdown]
# ### Paso 4: Unir restaurantes con reviews usando pandas
#
# Finalmente, conectamos cada restaurante con todas sus reviews. Esto se hace en memoria local usando pandas, que es súper eficiente.
#
# **Proceso:**
# 1. **Agrupamos reviews**: Tomamos todas las reviews y las agrupamos por business_id
# 2. **Creamos listas**: Convertimos las reviews de cada restaurante en una lista de diccionarios
# 3. **Contamos reviews**: Calculamos automáticamente cuántas reviews tiene cada restaurante
# 4. **Hacemos JOIN**: Unimos la información del restaurante con sus reviews
# 5. **Ordenamos**: Ponemos primero los restaurantes más populares (más reviews)
#
# **¿Por qué es rápido?**
# - Todo se hace en memoria RAM local
# - No hay latencia de red
# - Pandas está optimizado para estas operaciones
# - No dependemos de la conexión a MongoDB
#
# El resultado final: cada restaurante tiene toda su información más un array con todas sus reviews.

# %%
# JOIN local con pandas
print("Paso 4: Realizando JOIN local...")

join_start = time.time()

# Agrupar reviews por restaurante usando pandas
reviews_grouped = reviews_df.groupby('business_id').agg({
    'review_id': lambda x: x.tolist(),
    'user_id': lambda x: x.tolist(),
    'stars': lambda x: x.tolist(),
    'date': lambda x: x.tolist(),
    'text': lambda x: x.tolist(),
    'useful': lambda x: x.tolist(),
    'funny': lambda x: x.tolist(),
    'cool': lambda x: x.tolist()
}).reset_index()

# Convertir a formato de lista de diccionarios
def create_reviews_list(row):
    return [
        {
            'review_id': row['review_id'][i],
            'user_id': row['user_id'][i], 
            'stars': row['stars'][i],
            'date': row['date'][i],
            'text': row['text'][i],
            'useful': row['useful'][i],
            'funny': row['funny'][i],
            'cool': row['cool'][i]
        }
        for i in range(len(row['review_id']))
    ]

reviews_grouped['reviews'] = reviews_grouped.apply(create_reviews_list, axis=1)
reviews_grouped['total_reviews'] = reviews_grouped['reviews'].apply(len)

# Mantener solo las columnas necesarias
reviews_final = reviews_grouped[['business_id', 'reviews', 'total_reviews']]

# JOIN con restaurantes
result_df = restaurants_df.merge(reviews_final, on='business_id', how='inner')

# Ordenar por número de reviews
result_df = result_df.sort_values('total_reviews', ascending=False)

join_time = time.time() - join_start
print(f"JOIN completado en {join_time:.1f}s")
# Out:
# Paso 4: Realizando JOIN local...
# JOIN completado en 38.3s

# %% [markdown]
# ## Exportación de Resultados

# %% [markdown]
# ### Paso 5: Exportar resultado final
#
# Guardamos todos los datos procesados en un archivo JSON listo para análisis.
#
# **Características del archivo generado:**
# - **Formato**: JSON con indentación para fácil lectura
# - **Estructura**: Cada restaurante incluye todas sus reviews como un array
# - **Ordenamiento**: Por popularidad (restaurantes con más reviews primero)
# - **Encoding**: UTF-8 para manejar caracteres especiales correctamente
#
# **Métricas que mostramos al final:**
# - Cuántos restaurantes procesamos en total
# - Número total de reviews incluidas
# - Promedio de reviews por restaurante
# - Tiempo total que tomó todo el proceso
#
# ### ¿Qué tenemos ahora?
# Un dataset limpio y estructurado con:
# - ~52,000 restaurantes de Estados Unidos
# - ~5,000,000 reviews asociadas
# - Datos geográficos completos
# - Texto completo de reviews para análisis de NLP

# %%
# Exportar resultado
print("Paso 5: Exportando resultado...")

# Crear directorio si no existe
os.makedirs("../data", exist_ok=True)

# Convertir DataFrame a lista de diccionarios
results_list = result_df.to_dict('records')

# Exportar resultado como JSON
output_file = "../data/processed/restaurants_with_reviews.json"

with open(output_file, "w", encoding="utf-8") as f:
    json.dump(results_list, f, ensure_ascii=False, indent=2, default=str)

# Resumen de ejecución
total_time = time.time() - start_time
total_reviews = result_df['total_reviews'].sum()

print(f"\nExtracción completada")
print(f"Restaurantes procesados: {len(result_df):,}")
print(f"Total de reviews incluidas: {total_reviews:,}")
print(f"Tiempo de ejecución: {total_time:.1f}s ({total_time/60:.1f} minutos)")
print(f"Archivo generado: {output_file}")
print(f"\nDataset listo para análisis")
# Out:
# Paso 5: Exportando resultado...
#
# Extracción completada
# Restaurantes procesados: 52,268
# Total de reviews incluidas: 4,724,471
# Tiempo de ejecución: 2907.5s (48.5 minutos)
# Archivo generado: ../data/processed/restaurants_with_reviews.json
#
# Dataset listo para análisis
